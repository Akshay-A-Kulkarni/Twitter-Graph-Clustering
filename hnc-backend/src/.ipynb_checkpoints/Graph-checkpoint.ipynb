# %%
import json
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from networkx.readwrite import json_graph

# %matplotlib inline

# %%
from IngestionModule.twitterlistener import Dummy 

help(Dummy)

# %%
import _generateGraph as gg

help(gg.HashtagGraph())

# %%
import _loadData as l

help(l.LoadData())

# %% [markdown]
# ### Loading up the HTT dataset

# %%
# Loading and Specifying data types for csv
edgelist = pd.read_csv("/Users/akshaykulkarni/Downloads/twitter/edgelist", 
                       sep = "\t", names=["source","target"], dtype={'source': 'int', 'target': 'int'})

# Sampling the graph with rudimentary Max_Filter (can look into more elegant graph smapling methods)
e_filter = edgelist.query('`source` <= 100 & `target` <= 100')
e_filter = e_filter.sort_values(by=['source', 'target'])
e_filter

# %%
# Preloaded demo karate-community graph
g = nx.karate_club_graph()
fig1, ax1 = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(g, ax=ax1)

# Twitter graph
G = nx.from_pandas_edgelist(e_filter, "source", "target")
fig, ax = plt.subplots(1, 1, figsize=(10, 10));
nx.draw_networkx(G, ax=ax)

# %% [markdown]
# #### Ironically NetworkX has a 2d spectral graphing function which Draws the graph G with a spectral 2D layout.
#
# Using the unnormalized Laplacian, the layout shows possible clusters of nodes which are an approximation of the ratio cut. The positions are the entries of the second and third eigenvectors corresponding to the ascending eigenvalues starting from the second one.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10));
print("Sampled Spectral graph ")
nx.draw_spectral(G, ax=ax)

# %% [markdown]
# ##  Creating JSON dumps of graph object data for JS stuff

# %%
# defining custom exporting function
def exportToJSON(Graph, filename):
    nodes = [{'name': str(i)}
             for i in Graph.nodes()]
    links = [{'source': u[0], 'target': u[1]}
             for u in Graph.edges()]
    with open(filename+'.json', 'w') as f:
        json.dump({'nodes': nodes, 'links': links},
                  f, indent=4,)

# %%
exportToJSON(G,"graph")
# exportToJSON(g,"graph1")

# %%
# turns out networkx has fuctionality but the above func can be used to export minimal data 
# Converting graph objects into JSON to be read by D3
from networkx.readwrite import json_graph
data = json_graph.node_link_data(g)
with open('karate.json', 'w') as f:
    json.dump(data, f, indent=4)
    

from networkx.readwrite import json_graph
data = json_graph.node_link_data(G)
with open('HTT.json', 'w') as f:
    json.dump(data, f, indent=4)

# %% [markdown]
# # D3 visualisation  stuff

# %%
# D3 visualisations can be rendered in an ipynb notebook by injecting JS code in html cells ...
# for some god damn fucking reason its working just fine with the example karate graph 
# but does not render our HTT twitter graph I HAVE NO IDEA WHY ... i've been wrestling with d3 since Atlanta .. 
# though i have managed to view our graphs in d3 in other code cells just not in our notebook here.


# run html cell then run the next JS cell the graph will come as output of the html cell

# %%
# %%html
# <div id="d3-container"> </div>
#
# <style>
#
# .node {stroke: #fff; stroke-width: 1.5px;}
# .link {stroke: #999; stroke-opacity: .6;}
#
# </style>

# %%
# %%html
# <!DOCTYPE html>
# <meta charset="utf-8">
# <style>
#
# .links line {
#   stroke: #999;
#   stroke-opacity: 0.6;
# }
#
# .nodes circle {
#   stroke: black	;
#   stroke-width: 0px;
# }
#
# </style>
# <svg width="800" height="500"></svg>
# <script src="https://d3js.org/d3.v4.min.js"></script>
# <script>
#
# //create somewhere to put the force directed graph
# var svg = d3.select("svg"),
#     width = +svg.attr("width"),
#     height = +svg.attr("height");
#
# var radius = 5;
#
# var nodes_data =  [
#     {"name": "Lillian", "sex": "F"},
#     {"name": "Gordon", "sex": "M"},
#     {"name": "Sylvester", "sex": "M"},
#     {"name": "Mary", "sex": "F"},
#     {"name": "Helen", "sex": "F"},
#     {"name": "Jamie", "sex": "M"},
#     {"name": "Jessie", "sex": "F"},
#     {"name": "Ashton", "sex": "M"},
#     {"name": "Duncan", "sex": "M"},
#     {"name": "Evette", "sex": "F"},
#     {"name": "Mauer", "sex": "M"},
#     {"name": "Fray", "sex": "F"},
#     {"name": "Duke", "sex": "M"},
#     {"name": "Baron", "sex": "M"},
#     {"name": "Infante", "sex": "M"},
#     {"name": "Percy", "sex": "M"},
#     {"name": "Cynthia", "sex": "F"},
#     {"name": "Feyton", "sex": "M"},
#     {"name": "Lesley", "sex": "F"},
#     {"name": "Yvette", "sex": "F"},
#     {"name": "Maria", "sex": "F"},
#     {"name": "Lexy", "sex": "F"},
#     {"name": "Peter", "sex": "M"},
#     {"name": "Ashley", "sex": "F"},
#     {"name": "Finkler", "sex": "M"},
#     {"name": "Damo", "sex": "M"},
#     {"name": "Imogen", "sex": "F"}
#     ]
#
#
# var links_data = [
# 	{"source": "Sylvester", "target": "Gordon", "type":"A" },
#     {"source": "Sylvester", "target": "Lillian", "type":"A" },
#     {"source": "Sylvester", "target": "Mary", "type":"A"},
#     {"source": "Sylvester", "target": "Jamie", "type":"A"},
#     {"source": "Sylvester", "target": "Jessie", "type":"A"},
#     {"source": "Sylvester", "target": "Helen", "type":"A"},
#     {"source": "Helen", "target": "Gordon", "type":"A"},
#     {"source": "Mary", "target": "Lillian", "type":"A"},
#     {"source": "Ashton", "target": "Mary", "type":"A"},
#     {"source": "Duncan", "target": "Jamie", "type":"A"},
#     {"source": "Gordon", "target": "Jessie", "type":"A"},
#     {"source": "Sylvester", "target": "Fray", "type":"E"},
#     {"source": "Fray", "target": "Mauer", "type":"A"},
#     {"source": "Fray", "target": "Cynthia", "type":"A"},
#     {"source": "Fray", "target": "Percy", "type":"A"},
#     {"source": "Percy", "target": "Cynthia", "type":"A"},
#     {"source": "Infante", "target": "Duke", "type":"A"},
#     {"source": "Duke", "target": "Gordon", "type":"A"},
#     {"source": "Duke", "target": "Sylvester", "type":"A"},
#     {"source": "Baron", "target": "Duke", "type":"A"},
#     {"source": "Baron", "target": "Sylvester", "type":"E"},
#     {"source": "Evette", "target": "Sylvester", "type":"E"},
#     {"source": "Cynthia", "target": "Sylvester", "type":"E"},
#     {"source": "Cynthia", "target": "Jamie", "type":"E"},
#     {"source": "Mauer", "target": "Jessie", "type":"E"},
#     {"source": "Duke", "target": "Lexy", "type":"A"},
#     {"source": "Feyton", "target": "Lexy", "type":"A"},
#     {"source": "Maria", "target": "Feyton", "type":"A"},
#     {"source": "Baron", "target": "Yvette", "type":"E"},
#     {"source": "Evette", "target": "Maria", "type":"E"},
#     {"source": "Cynthia", "target": "Yvette", "type":"E"},
#     {"source": "Maria", "target": "Jamie", "type":"E"},
#     {"source": "Maria", "target": "Lesley", "type":"E"},
#     {"source": "Ashley", "target": "Damo", "type":"A"},
#     {"source": "Damo", "target": "Lexy", "type":"A"},
#     {"source": "Maria", "target": "Feyton", "type":"A"},
#     {"source": "Finkler", "target": "Ashley", "type":"E"},
#     {"source": "Sylvester", "target": "Maria", "type":"E"},
#     {"source": "Peter", "target": "Finkler", "type":"E"},
#     {"source": "Ashley", "target": "Gordon", "type":"E"},
#     {"source": "Maria", "target": "Imogen", "type":"E"}
#
# ]
#
#
# //set up the simulation and add forces
# var simulation = d3.forceSimulation()
# 					.nodes(nodes_data);
#
# var link_force =  d3.forceLink(links_data)
#                         .id(function(d) { return d.name; });
#
# var charge_force = d3.forceManyBody()
#     .strength(-100);
#
# var center_force = d3.forceCenter(width / 2, height / 2);
#
# simulation
#     .force("charge_force", charge_force)
#     .force("center_force", center_force)
#     .force("links",link_force);
#
#
# //add tick instructions:
# simulation.on("tick", tickActions );
#
# //add encompassing group for the zoom
# var g = svg.append("g")
#     .attr("class", "everything");
#
# //draw lines for the links
# var link = g.append("g")
#       .attr("class", "links")
#     .selectAll("line")
#     .data(links_data)
#     .enter().append("line")
#       .attr("stroke-width", 2)
#       .style("stroke", linkColour);
#
# //draw circles for the nodes
# var node = g.append("g")
#         .attr("class", "nodes")
#         .selectAll("circle")
#         .data(nodes_data)
#         .enter()
#         .append("circle")
#         .attr("r", radius)
#         .attr("fill", circleColour);
#
#
# //add drag capabilities
# var drag_handler = d3.drag()
# 	.on("start", drag_start)
# 	.on("drag", drag_drag)
# 	.on("end", drag_end);
#
# drag_handler(node);
#
#
# //add zoom capabilities
# var zoom_handler = d3.zoom()
#     .on("zoom", zoom_actions);
#
# zoom_handler(svg);
#
# /** Functions **/
#
# //Function to choose what color circle we have
# //Let's return blue for males and red for females
# function circleColour(d){
# 	if(d.sex =="M"){
# 		return "blue";
# 	} else {
# 		return "pink";
# 	}
# }
#
# //Function to choose the line colour and thickness
# //If the link type is "A" return green
# //If the link type is "E" return red
# function linkColour(d){
# 	if(d.type == "A"){
# 		return "green";
# 	} else {
# 		return "red";
# 	}
# }
#
# //Drag functions
# //d is the node
# function drag_start(d) {
#  if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
# }
#
# //make sure you can't drag the circle outside the box
# function drag_drag(d) {
#   d.fx = d3.event.x;
#   d.fy = d3.event.y;
# }
#
# function drag_end(d) {
#   if (!d3.event.active) simulation.alphaTarget(0);
#   d.fx = null;
#   d.fy = null;
# }
#
# //Zoom functions
# function zoom_actions(){
#     g.attr("transform", d3.event.transform)
# }
#
# function tickActions() {
#     //update circle positions each tick of the simulation
#        node
#         .attr("cx", function(d) { return d.x; })
#         .attr("cy", function(d) { return d.y; });
#
#     //update link positions
#     link
#         .attr("x1", function(d) { return d.source.x; })
#         .attr("y1", function(d) { return d.source.y; })
#         .attr("x2", function(d) { return d.target.x; })
#         .attr("y2", function(d) { return d.target.y; });
# }
# </script>

# %%
# %%javascript
# require.config({paths: {d3: "https://d3js.org/d3.v3.min"}});
# require(["d3"], function(d3) {
#     var width = 600,
#         height = 600;
#
#     var color = d3.scale.category10();
#
#     // Creating a force-directed dynamic graph layout.
#     var force = d3.layout.force()
#         .charge(-500)
#         .linkDistance(50)
#         .size([width, height]);
#
#     var svg = d3.select("#d3-container").select("svg")
#     if (svg.empty()) {
#         svg = d3.select("#d3-container").append("svg")
#                     .attr("width", width)
#                     .attr("height", height);
#     }
#
#     // load the JSON network file.
#     d3.json("karate.json", function(error, tgraph) {
#         // Within this block, the network has been loaded and stored
#         // load the nodes and links into the force-directed
#         // graph and initialise the dynamics.
#         force.nodes(tgraph.nodes)
#             .links(tgraph.links)
#             .start();
#
#         // We create a <line> SVG element for each link
#         // in the graph.
#         var link = svg.selectAll(".link")
#             .data(tgraph.links)
#             .enter().append("line")
#             .attr("class", "link");
#
#         // create a <circle> SVG element for each node
#         // in the graph, and we specify a few attributes.
#         var node = svg.selectAll(".node")
#             .data(tgraph.nodes)
#             .enter().append("circle")
#             .attr("class", "node")
#             .attr("r", 5)  // radius
#             .call(force.drag);
#
#         // The label each node its node number from the networkx graph.
#         node.append("title")
#             .text(function(d) { return d.id; });
#
#         // bind the positions of the SVG elements
#         // to the positions of the dynamic force-directed graph,
#         // at each time step.
#         force.on("tick", function() {
#             link.attr("x1", function(d) { return d.source.x; })
#                 .attr("y1", function(d) { return d.source.y; })
#                 .attr("x2", function(d) { return d.target.x; })
#                 .attr("y2", function(d) { return d.target.y; });
#
#             node.attr("cx", function(d) { return d.x; })
#                 .attr("cy", function(d) { return d.y; });
#         });
#     });
# });

# %% [markdown]
# -------------
#
# # COVID-19 Mined Dataset

# %%
import json
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from networkx.readwrite import json_graph

covid_raw = pd.read_csv("Data/Hashtag_Raw_Data/COVID19_hashtags7.csv").drop(["Unnamed: 0"], axis =1)
display(covid_raw)

print(covid_raw.nunique())

covid_raw['hashtag_id'] = covid_raw.groupby(['hashtag_x']).ngroup()
covid_raw.columns = ["tweet_id", "hashtag_name","tweet_hashtag_count", "hashtag_id"]

display(covid_raw)
covid_nodelist = covid_raw.drop_duplicates(['hashtag_name','hashtag_id'])[['hashtag_name','hashtag_id']].copy()

covid_nodelist = covid_nodelist.sort_values(by=['hashtag_id'])

covid_nodelist.to_csv("COVID19_NodeList.csv", index= False)

covid_nodelist

# %%
from itertools import combinations

covid_edgelist_src = covid_raw[["tweet_id", "hashtag_id"]]

list_of_edges = []

# Createing edges
for i, group in covid_edgelist_src.groupby(['tweet_id'])['hashtag_id']:
    # generate all combinations without replacement 
    # from the group of similar column pairs
    for u, v in combinations(group, 2):           
        list_of_edges.append(sorted([u, v]))
        


covid_edgelist = pd.DataFrame(list_of_edges, columns=["Source","Target"])


covid_edgelist = covid_edgelist.sort_values(by=['Source',"Target"])

covid_edgelist = covid_edgelist.groupby(covid_edgelist.columns.tolist()).size().reset_index().\
    rename(columns={0:'Edge_Freq'})

print(covid_edgelist.shape)
covid_edgelist

# %%
# Twitter graph
# temp = covid_edgelist.query('`Source` <= 50 & `Target` <= 50')
# display(temp)
C = nx.from_pandas_edgelist(covid_edgelist, "Source", "Target",['Edge_Freq'])
fig, ax = plt.subplots(1, 1, figsize=(20, 20));
nx.draw(C, ax=ax)

# %%
test = covid_nodelist.set_index('hashtag_id') 
test['Communities'] = np.arange(3509)

test

# %%
attrs = test.to_dict('index')
attrs
nx.set_node_attributes(C, attrs)

# %%
C.nodes[1299]

# %%
import networkx as nx
def connected_component_subgraphs(G):
    for c in nx.connected_components(G):
        yield G.subgraph(c).copy()
   

G.subgraph(c).copy() for c in connected_components(G)

connected_nodes = max(connected_component_subgraphs(C), key=len)

print(len(C.nodes))
print(len(connected_nodes.nodes))

# %%
connected_nodes.nodes[1299]['hashtag_name']

# %%
#Saving

covid_nodelist.to_csv("COVID19_NodeList.csv", index= False)
covid_edgelist.to_csv("COVID19_EdgeList.csv", index= False)

# %% [markdown]
# ## Experimental Stuff

# %% [markdown]
# Libs
# - pyvis ( main opt)
# - graphistry ( high capacity opt )
# - d3g (bs)

# %%
# !pwd

import os
os.chdir('..')
# !pwd

# %%
covid_raw = pd.read_csv("Data/Hashtag_Raw_Data/COVID19_hashtags7.csv").drop(["Unnamed: 0"], axis =1)
display(covid_raw)

print(covid_raw.nunique())

covid_raw['hashtag_id'] = covid_raw.groupby(['hashtag_x']).ngroup()
covid_raw.columns = ["tweet_id", "hashtag_name","tweet_hashtag_count", "hashtag_id"]

display(covid_raw)
covid_nodelist = covid_raw.drop_duplicates(['hashtag_name','hashtag_id'])[['hashtag_name','hashtag_id']].copy()

covid_nodelist = covid_nodelist.sort_values(by=['hashtag_id'])

covid_nodelist.to_csv("COVID19_NodeList.csv", index= False)

covid_nodelist

# %%
from itertools import combinations

covid_edgelist_src = covid_raw[["tweet_id", "hashtag_id"]]

test = covid_raw.query('`hashtag_id` <= 5')
display(test)

list_of_edges = []

# Createing edges
for i, group in test.groupby(['tweet_id'])['hashtag_id']:
    # generate all combinations without replacement 
    # from the group of similar column pairs
    for u, v in combinations(group, 2):           
        list_of_edges.append(sorted([u, v]))
        


covid_edgelist = pd.DataFrame(list_of_edges, columns=["Source","Target"])


covid_edgelist = covid_edgelist.sort_values(by=['Source',"Target"])



print(covid_edgelist.shape)
covid_edgelist

# %%
from itertools import combinations

covid_edgelist_src = covid_raw[["tweet_id", "hashtag_id"]]

test = covid_raw.query('`hashtag_id` <= 5')
display(test)

list_of_edges = []

# Createing edges
for i, group in covid_edgelist_src.groupby(['tweet_id'])['hashtag_id']:
    # generate all combinations without replacement 
    # from the group of similar column pairs
    for u, v in combinations(group, 2):           
        list_of_edges.append([u, v])
        


covid_edgelist = pd.DataFrame(list_of_edges, columns=["Source","Target"])


covid_edgelist = covid_edgelist.sort_values(by=['Source',"Target"])



print(covid_edgelist.shape)
covid_edgelist.drop_duplicates(['Source','Target'])

# %%
island = pd.read_csv("/Users/akshaykulkarni/Downloads/connected_edges.csv")
C = nx.from_pandas_edgelist(island, "Source", "Target")
# fig, ax = plt.subplots(1, 1, figsize=(20, 20))
# nx.draw_kamada_kawai(C, ax=ax)

# %%
from networkx.readwrite import json_graph
data = json_graph.node_link_data(C)
with open('island.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
from pyvis.network import Network as pyNet
import networkx as nx
G = pyNet(notebook = True)
G.show_buttons(filter_=['physics'])
G.from_nx(C)
G.show('island2.html')

# %%
island[island['Source'] == 1299]

# %%
import pandas as pd
nodes = pd.read_csv('data/Island/connected_nodes.csv')

# %%
nodes[nodes['hashtag_id'].isin([2313,2810,2824,2865])]

# %%
nodes[nodes['hashtag_id'].isin([1265,1938,2287,2288,2327,2550,2682,3427])]

# %%
comm_35 = [735,1111,1563,1889,1980,1985,2052,2099,2131,2148,2380,2381,2389,2515,2519,2608,2877,2988,3054,3196,3234,3326,3339,3455]
nodes[nodes['hashtag_id'].isin(comm_35)]

# %%
GN_41= [621, 1292, 1898, 2422, 2648, 2649, 3382]
nodes[nodes['hashtag_id'].isin(GN_41)]

# %%
GN_40= [334, 1604, 2737, 2738, 2802, 2814, 2815, 3101]
nodes[nodes['hashtag_id'].isin(GN_40)]

# %%
nodes[nodes['hashtag_id'].isin([1265,1938,2287,2288,2327,2550,2682,3427])]

# %%
comm_35 = [735,1111,1563,1889,1980,1985,2052,2099,2131,2148,2380,2381,2389,2515,2519,2608,2877,2988,3054,3196,3234,3326,3339,3455]
nodes[nodes['hashtag_id'].isin(comm_35)]

# %%
GN_41= [621, 1292, 1898, 2422, 2648, 2649, 3382]
nodes[nodes['hashtag_id'].isin(GN_41)]

# %%
GN_40= [334, 1604, 2737, 2738, 2802, 2814, 2815, 3101]
nodes[nodes['hashtag_id'].isin(GN_40)]

# %%
import json

with open('GN_SY_Test_1.json') as f:
    data = json.load(f)

print(data)
# Out:
# {'directed': False, 'multigraph': False, 'graph': {}, 'nodes': [{'hashtag_name': '1000daysartwithnik', 'CNM_Label': 15, 'id': 1}, {'hashtag_name': 'day76', 'CNM_Label': 15, 'id': 2228}, {'hashtag_name': 'nikartseries', 'CNM_Label': 15, 'id': 2828}, {'hashtag_name': 'socialdistancing', 'CNM_Label': 15, 'id': 3175}, {'hashtag_name': '16marzo', 'CNM_Label': 27, 'id': 6}, {'hashtag_name': 'iorestoacasa', 'CNM_Label': 27, 'id': 2589}, {'hashtag_name': 'salvini', 'CNM_Label': 27, 'id': 3098}, {'hashtag_name': '1A', 'CNM_Label': 2, 'id': 7}, {'hashtag_name': 'censorship', 'CNM_Label': 2, 'id': 2092}, {'hashtag_name': 'google', 'CNM_Label': 2, 'id': 2448}, {'hashtag_name': '2019nCoV', 'CNM_Label': 9, 'id': 10}, {'hashtag_name': 'Airlines', 'CNM_Label': 9, 'id': 74}, {'hashtag_name': 'Biohazard', 'CNM_Label': 9, 'id': 196}, {'hashtag_name': 'China', 'CNM_Label': 2, 'id': 319}, {'hashtag_name': 'Cunard', 'CNM_Label': 9, 'id': 399}, {'hashtag_name': 'Monsters', 'CNM_Label': 9, 'id': 1048}, {'hashtag_name': 'NHS', 'CNM_Label': 20, 'id': 1088}, {'hashtag_name': 'ResidentEvil', 'CNM_Label': 9, 'id': 1338}, {'hashtag_name': 'UK', 'CNM_Label': 9, 'id': 1719}, {'hashtag_name': 'Virus', 'CNM_Label': 9, 'id': 1768}, {'hashtag_name': 'WHO', 'CNM_Label': 9, 'id': 1785}, {'hashtag_name': 'bali', 'CNM_Label': 9, 'id': 1964}, {'hashtag_name': 'confinementtotal', 'CNM_Label': 7, 'id': 2157}, {'hashtag_name': 'economic', 'CNM_Label': 9, 'id': 2301}, {'hashtag_name': 'nCoV2019', 'CNM_Label': 9, 'id': 2801}, {'hashtag_name': 'publichealth', 'CNM_Label': 9, 'id': 3013}, {'hashtag_name': 'theatre', 'CNM_Label': 9, 'id': 3295}, {'hashtag_name': '20seconds', 'CNM_Label': 20, 'id': 12}, {'hashtag_name': 'health', 'CNM_Label': 20, 'id': 2491}, {'hashtag_name': 'jocoderm', 'CNM_Label': 20, 'id': 2622}, {'hashtag_name': 'washthosehands', 'CNM_Label': 20, 'id': 3409}, {'hashtag_name': '25thAmendmentNow', 'CNM_Label': 16, 'id': 13}, {'hashtag_name': 'GOPCorruptionOverCountry', 'CNM_Label': 16, 'id': 614}, {'hashtag_name': '2plan', 'CNM_Label': 11, 'id': 15}, {'hashtag_name': 'economy', 'CNM_Label': 11, 'id': 2306}, {'hashtag_name': 'ftse', 'CNM_Label': 11, 'id': 2411}, {'hashtag_name': 'ftse100', 'CNM_Label': 11, 'id': 2412}, {'hashtag_name': '316Day', 'CNM_Label': 1, 'id': 17}, {'hashtag_name': 'QuarantineLife', 'CNM_Label': 1, 'id': 1299}, {'hashtag_name': 'StoneCold', 'CNM_Label': 1, 'id': 1555}, {'hashtag_name': 'WWERaw', 'CNM_Label': 1, 'id': 1792}, {'hashtag_name': 'wwe', 'CNM_Label': 1, 'id': 3461}, {'hashtag_name': '3D', 'CNM_Label': 8, 'id': 18}, {'hashtag_name': 'Polygonal', 'CNM_Label': 8, 'id': 1258}, {'hashtag_name': 'hospital', 'CNM_Label': 6, 'id': 2522}, {'hashtag_name': 'icon', 'CNM_Label': 8, 'id': 2546}, {'hashtag_name': 'pandemic', 'CNM_Label': 8, 'id': 2898}, {'hashtag_name': 'tech', 'CNM_Label': 14, 'id': 3274}, {'hashtag_name': '3dprinting', 'CNM_Label': 2, 'id': 21}, {'hashtag_name': 'diy', 'CNM_Label': 2, 'id': 2265}, {'hashtag_name': 'italy', 'CNM_Label': 2, 'id': 2605}, {'hashtag_name': 'respirator', 'CNM_Label': 2, 'id': 3069}, {'hashtag_name': '3weeksprevents', 'CNM_Label': 12, 'id': 22}, {'hashtag_name': 'StayTheFHome', 'CNM_Label': 1, 'id': 1544}, {'hashtag_name': 'love', 'CNM_Label': 12, 'id': 2706}, {'hashtag_name': '4thturning', 'CNM_Label': 36, 'id': 26}, {'hashtag_name': 'toiletpaper', 'CNM_Label': 36, 'id': 3320}, {'hashtag_name': '51stState', 'CNM_Label': 31, 'id': 27}, {'hashtag_name': 'America', 'CNM_Label': 31, 'id': 87}, {'hashtag_name': 'PuertoRico', 'CNM_Label': 31, 'id': 1285}, {'hashtag_name': 'manufacturer', 'CNM_Label': 31, 'id': 2726}, {'hashtag_name': 'pharmaceutical', 'CNM_Label': 31, 'id': 2937}, {'hashtag_name': '5G', 'CNM_Label': 18, 'id': 28}, {'hashtag_name': 'Huawei', 'CNM_Label': 18, 'id': 737}, {'hashtag_name': 'Wuhan', 'CNM_Label': 18, 'id': 1855}, {'hashtag_name': 'eHealth', 'CNM_Label': 18, 'id': 2294}, {'hashtag_name': '603life', 'CNM_Label': 8, 'id': 29}, {'hashtag_name': 'safety', 'CNM_Label': 8, 'id ...

# %%
gn_comms = {}
for i in data['nodes']:
    gn_comms[i['id']] = i['CNM_Label']

# %%
gn_comms
# Out:
# {1: 15,
#  2228: 15,
#  2828: 15,
#  3175: 15,
#  6: 27,
#  2589: 27,
#  3098: 27,
#  7: 2,
#  2092: 2,
#  2448: 2,
#  10: 9,
#  74: 9,
#  196: 9,
#  319: 2,
#  399: 9,
#  1048: 9,
#  1088: 20,
#  1338: 9,
#  1719: 9,
#  1768: 9,
#  1785: 9,
#  1964: 9,
#  2157: 7,
#  2301: 9,
#  2801: 9,
#  3013: 9,
#  3295: 9,
#  12: 20,
#  2491: 20,
#  2622: 20,
#  3409: 20,
#  13: 16,
#  614: 16,
#  15: 11,
#  2306: 11,
#  2411: 11,
#  2412: 11,
#  17: 1,
#  1299: 1,
#  1555: 1,
#  1792: 1,
#  3461: 1,
#  18: 8,
#  1258: 8,
#  2522: 6,
#  2546: 8,
#  2898: 8,
#  3274: 14,
#  21: 2,
#  2265: 2,
#  2605: 2,
#  3069: 2,
#  22: 12,
#  1544: 1,
#  2706: 12,
#  26: 36,
#  3320: 36,
#  27: 31,
#  87: 31,
#  1285: 31,
#  2726: 31,
#  2937: 31,
#  28: 18,
#  737: 18,
#  1855: 18,
#  2294: 18,
#  29: 8,
#  3096: 8,
#  3233: 8,
#  38: 12,
#  227: 26,
#  713: 12,
#  42: 9,
#  417: 9,
#  1356: 9,
#  1999: 9,
#  49: 7,
#  64: 7,
#  1483: 7,
#  56: 1,
#  129: 1,
#  1534: 1,
#  57: 4,
#  69: 4,
#  60: 7,
#  62: 7,
#  1236: 7,
#  2892: 7,
#  3350: 7,
#  61: 7,
#  577: 7,
#  63: 26,
#  845: 26,
#  846: 38,
#  1557: 26,
#  67: 2,
#  802: 2,
#  813: 2,
#  1505: 23,
#  68: 12,
#  2695: 12,
#  117: 4,
#  445: 4,
#  697: 4,
#  905: 4,
#  1494: 4,
#  1607: 4,
#  1875: 4,
#  1885: 4,
#  70: 4,
#  234: 9,
#  1368: 9,
#  1765: 9,
#  76: 6,
#  272: 6,
#  1508: 6,
#  2495: 6,
#  80: 9,
#  2492: 9,
#  85: 5,
#  273: 5,
#  1760: 5,
#  86: 19,
#  155: 19,
#  191: 19,
#  372: 19,
#  500: 19,
#  1296: 19,
#  1832: 19,
#  1998: 19,
#  3166: 19,
#  368: 31,
#  434: 16,
#  460: 31,
#  579: 31,
#  1199: 31,
#  1208: 22,
#  1336: 5,
#  1431: 19,
#  1717: 31,
#  2061: 31,
#  2410: 9,
#  2426: 31,
#  2636: 31,
#  3481: 9,
#  3482: 9,
#  90: 19,
#  1532: 3,
#  1682: 5,
#  1699: 19,
#  91: 5,
#  1445: 5,
#  1592: 5,
#  102: 3,
#  561: 3,
#  1212: 3,
#  104: 12,
#  105: 12,
#  107: 9,
#  268: 9,
#  952: 9,
#  3375: 9,
#  108: 30,
#  501: 30,
#  778: 30,
#  895: 30,
#  1759: 30,
#  112: 1,
#  115: 6,
#  1073: 6,
#  2193: 6,
#  3503: 6,
#  3504: 6,
#  119: 13,
#  730: 13,
#  1603: 13,
#  1726: 18,
#  2858: 13,
#  121: 1,
#  1290: 1,
#  1645: 1,
#  2907: 1,
#  3144: 1,
#  126: 34,
#  638: 19,
#  733: 34,
#  876: 34,
#  1099: 34,
#  1408: 34,
#  1409: 34,
#  131: 8,
#  341: 8,
#  747: 8,
#  750: 8,
#  751: 8,
#  791: 8,
#  133: 3,
#  1529: 3,
#  1804: 3,
#  134: 6,
#  2873: 6,
#  135: 27,
#  2793: 27,
#  2794: 27,
#  2819: 27,
#  3031: 27,
#  3383: 27,
#  3391: 27,
#  136: 9,
#  1599: 9,
#  2406: 9,
#  137: 1,
#  139: 18,
#  1970: 18,
#  2088: 18,
#  140: 12,
#  3058: 12,
#  142: 5,
#  181: 5,
#  355: 5,
#  356: 5,
#  458: 5,
#  785: 5,
#  837: 5,
#  983: 5,
#  1035: 5,
#  1528: 5,
#  143: 30,
#  2147: 30,
#  3389: 30,
#  149: 17,
#  228: 17,
#  311: 17,
#  466: 10,
#  765: 17,
#  807: 17,
#  917: 17,
#  1013: 17,
#  1129: 17,
#  1131: 17,
#  1132: 17,
#  1160: 23,
#  1795: 17,
#  2820: 17,
#  150: 1,
#  1452: 1,
#  151: 1,
#  2239: 1,
#  2657: 1,
#  2913: 1,
#  153: 9,
#  797: 9,
#  156: 5,
#  1364: 5,
#  1626: 5,
#  1677: 5,
#  1817: 5,
#  157: 15,
#  3200: 15,
#  158: 3,
#  1018: 3,
#  2480: 3,
#  159: 2,
#  1369: 2,
#  1444: 2,
#  3024: 11,
#  162: 35,
#  242: 35,
#  721: 35,
#  729: 35,
#  1728: 35,
#  164: 7,
#  1240: 7,
#  1491: 7,
#  169: 32,
#  576: 32,
#  1510: 32,
#  1531: 32,
#  1542: 32,
#  1634: 32,
#  2477: 32,
#  170: 3,
#  313: 3,
#  1530: 3,
#  2778: 3,
#  172: 24,
#  677: 24,
#  694: 24,
#  1610: 24,
#  173: 1,
#  1812: 1,
#  3038: 1,
#  3121: 1,
#  3279: 1,
#  174: 10,
#  408: 10,
#  1076: 10,
#  1101: 10,
#  1550: 10,
#  1673: 10,
#  176: 1,
#  2961: 16,
#  178: 2,
#  1365: 2,
#  179: 23,
#  858: 5,
#  2969: 23,
#  3275: 23,
#  198: 1,
#  432: 5,
#  435: 5,
#  536: 5,
#  656: 5,
#  897: 5,
#  984: 5,
#  1003: 5,
#  1123: 5,
#  1451: 5,
#  187: 9,
#  428: 9,
#  189: 22,
#  815: 22,
#  839: 22,
#  1320: 22,
#  1791: 22,
#  1853: 22,
#  190: 9,
#  194: 21,
#  907: 21,
#  1049: 21,
#  2679: 21,
#  195: 10,
#  773: 10,
#  1040: 10,
#  1186: 10,
#  1410: 10,
#  2776: 10,
#  202: 1,
#  203: 14,
#  395: 14,
#  516: 14,
#  570: 14,
#  589: 14,
#  800: 14,
#  207: 23,
#  782: 23,
#  1762: 23,
#  2786: 23,
#  210: 21,
#  2021: 21,
#  211: 9,
#  231: 9,
#  2027: 9,
#  212: 2,
#  1739: 2,
#  2760: 2,
#  213: 24,
#  1811: 24,
#  3168: 24,
#  223: 20,
#  565: 20,
#  1173: 20,
#  1250: 20,
#  225: 7,
#  1485: 1,
#  3068: 7,
#  226: 19,
#  944: 26,
#  1128: 4,
#  1156: 26,
#  1315: 26,
#  1358: 26,
#  1669: 10,
#  1796: 26,
#  1797: 26,
#  271: 17,
#  504: 17,
#  995: 17,
#  1159: 17,
#  1637: 17,
#  1641: 17,
#  1672: 17,
#  1700: 17,
#  1849: 17,
#  2175: 17,
#  229: 10,
#  1042: 10,
#  1330: 10,
#  495: 9,
#  544: 9,
#  605: 9,
#  982: 9,
#  3395: 9,
#  233: 6,
#  1000: 6,
#  1935: 6,
#  3015: 6,
#  235: 34,
#  543: 34,
#  1424: 34,
#  237: 9,
#  525: 9,
#  238: 15,
#  293: 15,
#  580: 15,
#  244: 17,
#  1334: 15,
#  245: 26,
#  370: 26,
#  986: 26,
#  1554: 26,
#  1612: 4,
#  1846: 26,
#  250: 17,
#  1252: 17,
#  1713: 17,
#  251: 2,
#  1023: 2,
#  2006: 2,
#  2429: 2,
#  252: 5,
#  366: 5,
#  440: 5,
#  477: 5,
#  595: 5,
#  612: 5,
#  254: 13,
#  255: 25,
#  2812: 25,
#  3206: 25,
#  3475: 25,
#  256: 18,
#  1370: 18,
#  1856: 18,
#  1857: 18,
#  1858: 18,
#  262: 29,
#  488: 29,
#  490: 29,
#  521: 29,
#  746: 29,
#  263: 1,
#  981: 1,
#  269: 6,
#  2583: 6,
#  3381: 6,
#  270: 10,
#  1041: 10,
#  1319: 10,
#  1127: 2,
#  1742: 2,
#  274: 30,
#  2091: 30,
#  3138: 30,
#  276: 2,
#  278: 3,
#  945: 3,
#  1502: 2,
#  1835: 3,
#  281: 22,
#  538: 22,
#  2933: 22,
#  282: 14,
#  1425: 14,
#  3066: 14,
#  283: 10,
#  284: 5,
#  505: 5,
#  584: 5,
#  833: 5,
#  1271: 5,
#  286: 19,
#  1525: 19,
#  287: 30,
#  288: 18,
#  1681: 18,
#  289: 6,
#  711: 7,
#  2067: 6,
#  296: 4,
#  892: 4,
#  1251: 4,
#  297: 2,
#  2277: 2,
#  298: 23,
#  299: 7,
#  301: 7,
#  2340: 7,
#  3119: 7,
#  302: 26,
#  1977: 26,
#  3034: 26,
#  314: 19,
#  315: 2,
#  827: 2,
#  2615: 2,
#  317: 23,
#  796: 23,
#  819: 23,
#  318: 18,
#  324: 2,
#  429: 10,
#  523: 16,
#  779: 2,
#  809: 2,
#  883: 2,
#  1109: 2,
#  1202: 2,
#  1460: 2,
#  1764: 2,
#  1800: 2,
#  2104: 2,
#  2139: 2,
#  2185: 2,
#  2304: 2,
#  2322: 2,
#  2437: 11,
#  2557: 2,
#  2647: 2,
#  2803: 2,
#  3165: 2,
#  3452: 4,
#  321: 18,
#  601: 18,
#  603: 18,
#  323: 15,
#  2644: 15,
#  2887: 15,
#  2968: 15,
#  3073: 15,
#  3264: 15,
#  330: 18,
#  1172: 18,
#  332: 27,
#  1242: 27,
#  334: 40,
#  2737: 40,
#  2802: 40,
#  2814: 40,
#  2815: 40,
#  3101: 40,
#  337: 13,
#  3229: 13,
#  340: 22,
#  420: 22,
#  1374: 22,
#  1694: 22,
#  1859: 22,
#  2800: 22,
#  1951: 8,
#  342: 30,
#  343: 30,
#  1978: 30,
#  344: 10,
#  352: 7,
#  353: 15,
#  575: 15,
#  2069: 15,
#  2200: 15,
#  2365: 15,
#  410: 5,
#  830: 5,
#  1021: 5,
#  1830: 5,
#  358: 10,
#  1551: 10,
#  1552: 10,
#  361: 35,
#  1140: 35,
#  1450: 35,
#  362: 3,
#  2258: 3,
#  369: 30,
#  378: 5,
#  1435: 5,
#  1440: 5,
#  388: 8,
#  885: 8,
#  3022: 8,
#  390: 10,
#  1826: 10,
#  472: 14,
#  2008: 14,
#  2764: 14,
#  397: 2,
#  455: 2,
#  804: 2,
#  954: 2,
#  401: 4,
#  684: 4,
#  977: 4,
#  1614: 4,
#  402: 13,
#  2214: 13,
#  2224: 13,
#  2571: 13,
#  2921: 13,
#  403: 21,
#  1906: 21,
#  3343: 21,
#  406: 17,
#  407: 18,
#  3228: 13,
#  416: 13,
#  1232: 13,
#  1273: 13,
#  2222: 13,
#  421: 10,
#  1043: 10,
#  422: 5,
#  1163: 5,
#  423: 15,
#  426: 10,
#  596: 4,
#  639: 9,
#  433: 10,
#  431: 5,
#  470: 5,
#  906: 5,
#  999: 5,
#  1750: 5,
#  2039: 5,
#  2452: 5,
#  552: 16,
#  553: 16,
#  896: 5,
#  2062: 16,
#  2152: 5,
#  2677: 16,
#  3346: 16,
#  439: 15,
#  454: 15,
#  512: 15,
#  1153: 15,
#  443: 8,
#  447: 3,
#  3252: 3,
#  452: 3,
#  1734: 16,
#  3329: 21,
#  459: 32,
#  2633: 32,
#  461: 21,
#  462: 21,
#  1608: 21,
#  640: 21,
#  641: 21,
#  2086: 21,
#  463: 1,
#  465: 10,
#  2852: 10,
#  2853: 10,
#  1053: 10,
#  1692: 16,
#  2473: 10,
#  2783: 10,
#  2985: 10,
#  471: 4,
#  795: 4,
#  1253: 4,
#  1513: 4,
#  1571: 4,
#  474: 4,
#  2024: 4,
#  2901: 4,
#  475: 8,
#  478: 22,
#  479: 22,
#  572: 22,
#  573: 22,
#  1642: 22,
#  484: 14,
#  1447: 14,
#  2409: 14,
#  2701: 14,
#  3246: 14,
#  3276: 14,
#  492: 10,
#  493: 31,
#  2662: 31,
#  496: 33,
#  1360: 33,
#  1372: 33,
#  1385: 33,
#  748: 30,
#  909: 17,
#  993: 17,
#  1054: 17,
#  1380: 17,
#  1462: 17,
#  1568: 17,
#  1707: 17,
#  2038: 17,
#  3258: 17,
#  3491: 17,
#  3494: 17,
#  509: 31,
#  680: 31,
#  1815: 31,
#  514: 10,
#  1038: 10,
#  1526: 10,
#  1840: 10,
#  1876: 10,
#  910: 14,
#  1047: 14,
#  2324: 14,
#  520: 2,
#  843: 2,
#  2528: 2,
#  522: 3,
#  2697: 16,
#  526: 22,
#  528: 3,
#  581: 3,
#  1511: 3,
#  1704: 3,
#  532: 32,
#  1142: 32,
#  535: 16,
#  1693: 16,
#  1916: 16,
#  2628: 16,
#  2719: 16,
#  3023: 16,
#  3067: 16,
#  3396: 16,
#  3462: 16,
#  548: 3,
#  549: 8,
#  2255: 8,
#  2476: 8,
#  550: 14,
#  1119: 16,
#  1775: 16,
#  554: 8,
#  1044: 8,
#  1301: 8,
#  555: 32,
#  1032: 32,
#  1628: 32,
#  557: 5,
#  604: 5,
#  559: 1,
#  658: 1,
#  3474: 1,
#  564: 15,
#  1138: 15,
#  566: 9,
#  2081: 9,
#  571: 3,
#  657: 7,
#  686: 7,
#  728: 3,
#  847: 7,
#  863: 31,
#  879: 7,
#  1189: 7,
#  1190: 7,
#  1191: 7,
#  1298: 12,
#  1346: 7,
#  1546: 31,
#  1619: 7,
#  1653: 7,
#  1743: 7,
#  1820: 7,
#  1844: 12,
#  2003: 7,
#  2082: 7,
#  2590: 27,
#  2635: 7,
#  3026: 27,
#  3056: 7,
#  3410: 7,
#  3077: 15,
#  582: 22,
#  1248: 22,
#  1674: 5,
#  1821: 22,
#  583: 35,
#  585: 5,
#  1247: 4,
#  1347: 5,
#  591: 30,
#  2004: 30,
#  653: 4,
#  965: 4,
#  1587: 4,
#  1736: 4,
#  597: 10,
#  1793: 38,
#  1828: 10,
#  598: 4,
#  762: 4,
#  1005: 4,
#  600: 10,
#  878: 10,
#  610: 4,
#  1201: 4,
#  780: 5,
#  613: 16,
#  616: 16,
#  856: 16,
#  1058: 16,
#  2449: 16,
#  620: 1,
#  650: 1,
#  621: 41,
#  2422: 41,
#  2648: 41,
#  2649: 41,
#  627: 4,
#  1613: 4,
#  632: 2,
#  859: 2,
#  1671: 2,
#  1702: 2,
#  633: 5,
#  958: 5,
#  1774: 5,
#  634: 12,
#  2022: 12,
#  3174: 12,
#  2060: 9,
#  2243: 9,
#  2321: 34,
#  2509: 9,
#  644: 1,
#  645: 1,
#  646: 1,
#  647: 8,
#  700: 8,
#  648: 20,
#  1377: 20,
#  1396: 20,
#  649: 33,
#  652: 6,
#  3182: 6,
#  832: 4,
#  1946: 4,
#  2366: 4,
#  2833: 4,
#  2976: 4,
#  2977: 4,
#  3062: 4,
#  3088: 4,
#  3124: 4,
#  3451: 11,
#  669: 18,
#  674: 18,
#  2632: 24,
#  2664: 24,
#  3115: 24,
#  681: 8,
#  687: 10,
#  1484: 10,
#  1536: 10,
#  688: 9,
#  689: 9,
#  693: 25,
#  1783: 25,
#  696: 18,
#  1860: 18,
#  709: 4,
#  793: 4,
#  886: 4,
#  912: 4,
#  998: 4,
#  1052: 4,
#  1406: 4,
#  1654: 4,
#  1831: 4,
#  2493: 4,
#  698: 2,
#  699: 13,
#  971: 13,
#  3040: 13,
#  701: 21,
#  3345: 21,
#  703: 20,
#  1459: 20,
#  706: 29,
#  2501: 29,
#  708: 5,
#  1147: 5,
#  3146: 5,
#  717: 6,
#  2357: 6,
#  3238: 6,
#  720: 22,
#  722: 5,
#  1569: 5,
#  1675: 5,
#  1676: 5,
#  749: 3,
#  3356: 3,
#  731: 1,
#  732: 2,
#  2350: 34,
#  3061: 34,
#  734: 18,
#  1519: 18,
#  2158: 18,
#  2189: 18,
#  735: 28,
#  1985: 28,
#  2608: 28,
#  738: 18,
#  1650: 18,
#  1861: 18,
#  739: 9,
#  741: 10,
#  1428: 29,
#  761: 2,
#  1166: 2,
#  763: 2,
#  766: 27,
#  1871: 27,
#  1873: 27,
#  2156: 12,
#  767: 7,
#  774: 1,
#  1449: 1,
#  777: 39,
#  2268: 39,
#  1882: 2,
#  781: 12,
#  867: 23,
#  2856: 23,
#  3288: 23,
#  788: 19,
#  1056: 19,
#  1196: 19,
#  3347: 19,
#  790: 3,
#  1779: 3,
#  1990: 3,
#  1991: 3,
#  1808: 8,
#  792: 2,
#  798: 12,
#  806: 12,
#  1481: 12,
#  2042: 12,
#  2582: 12,
#  801: 6,
#  2382: 6,
#  869: 2,
#  1276: 2,
#  3100: 35,
#  803: 6,
#  1794: 2,
#  2326: 2,
#  3248: 12,
#  805: 20,
#  1517: 20,
#  2958: 17,
#  2181: 2,
#  2606: 2,
#  1009: 2,
#  1453: 2,
#  2575: 14,
#  814: 6,
#  818: 33,
#  1348: 33,
#  822: 10,
#  823: 10,
#  1107: 10,
#  824: 23,
#  888: 23,
#  825: 23,
#  826: 23,
#  828: 2,
#  829: 2,
#  1661: 2,
#  1662: 2,
#  3112: 2,
#  3239: 2,
#  834: 12,
#  2588: 12,
#  2728: 12,
#  2934: 12,
#  3480: 12,
#  838: 5,
#  841: 1,
#  1187: 38,
#  1289: 38,
#  1588: 38,
#  1683: 38,
#  2221: 38,
#  3299: 38,
#  848: 8,
#  849: 8,
#  2641: 8,
#  2643: 8,
#  850: 10,
#  855: 3,
#  857: 2,
#  865: 18,
#  ...}

# %%
for e in data['links']:
    if gn_comms[e['source']] == gn_comms[e['target']]:
        e['color'] = gn_comms[e['source']]
    else:
        e['color'] = 0

# %%
data
# Out:
# {'directed': False,
#  'multigraph': False,
#  'graph': {},
#  'nodes': [{'hashtag_name': '1000daysartwithnik', 'CNM_Label': 15, 'id': 1},
#   {'hashtag_name': 'day76', 'CNM_Label': 15, 'id': 2228},
#   {'hashtag_name': 'nikartseries', 'CNM_Label': 15, 'id': 2828},
#   {'hashtag_name': 'socialdistancing', 'CNM_Label': 15, 'id': 3175},
#   {'hashtag_name': '16marzo', 'CNM_Label': 27, 'id': 6},
#   {'hashtag_name': 'iorestoacasa', 'CNM_Label': 27, 'id': 2589},
#   {'hashtag_name': 'salvini', 'CNM_Label': 27, 'id': 3098},
#   {'hashtag_name': '1A', 'CNM_Label': 2, 'id': 7},
#   {'hashtag_name': 'censorship', 'CNM_Label': 2, 'id': 2092},
#   {'hashtag_name': 'google', 'CNM_Label': 2, 'id': 2448},
#   {'hashtag_name': '2019nCoV', 'CNM_Label': 9, 'id': 10},
#   {'hashtag_name': 'Airlines', 'CNM_Label': 9, 'id': 74},
#   {'hashtag_name': 'Biohazard', 'CNM_Label': 9, 'id': 196},
#   {'hashtag_name': 'China', 'CNM_Label': 2, 'id': 319},
#   {'hashtag_name': 'Cunard', 'CNM_Label': 9, 'id': 399},
#   {'hashtag_name': 'Monsters', 'CNM_Label': 9, 'id': 1048},
#   {'hashtag_name': 'NHS', 'CNM_Label': 20, 'id': 1088},
#   {'hashtag_name': 'ResidentEvil', 'CNM_Label': 9, 'id': 1338},
#   {'hashtag_name': 'UK', 'CNM_Label': 9, 'id': 1719},
#   {'hashtag_name': 'Virus', 'CNM_Label': 9, 'id': 1768},
#   {'hashtag_name': 'WHO', 'CNM_Label': 9, 'id': 1785},
#   {'hashtag_name': 'bali', 'CNM_Label': 9, 'id': 1964},
#   {'hashtag_name': 'confinementtotal', 'CNM_Label': 7, 'id': 2157},
#   {'hashtag_name': 'economic', 'CNM_Label': 9, 'id': 2301},
#   {'hashtag_name': 'nCoV2019', 'CNM_Label': 9, 'id': 2801},
#   {'hashtag_name': 'publichealth', 'CNM_Label': 9, 'id': 3013},
#   {'hashtag_name': 'theatre', 'CNM_Label': 9, 'id': 3295},
#   {'hashtag_name': '20seconds', 'CNM_Label': 20, 'id': 12},
#   {'hashtag_name': 'health', 'CNM_Label': 20, 'id': 2491},
#   {'hashtag_name': 'jocoderm', 'CNM_Label': 20, 'id': 2622},
#   {'hashtag_name': 'washthosehands', 'CNM_Label': 20, 'id': 3409},
#   {'hashtag_name': '25thAmendmentNow', 'CNM_Label': 16, 'id': 13},
#   {'hashtag_name': 'GOPCorruptionOverCountry', 'CNM_Label': 16, 'id': 614},
#   {'hashtag_name': '2plan', 'CNM_Label': 11, 'id': 15},
#   {'hashtag_name': 'economy', 'CNM_Label': 11, 'id': 2306},
#   {'hashtag_name': 'ftse', 'CNM_Label': 11, 'id': 2411},
#   {'hashtag_name': 'ftse100', 'CNM_Label': 11, 'id': 2412},
#   {'hashtag_name': '316Day', 'CNM_Label': 1, 'id': 17},
#   {'hashtag_name': 'QuarantineLife', 'CNM_Label': 1, 'id': 1299},
#   {'hashtag_name': 'StoneCold', 'CNM_Label': 1, 'id': 1555},
#   {'hashtag_name': 'WWERaw', 'CNM_Label': 1, 'id': 1792},
#   {'hashtag_name': 'wwe', 'CNM_Label': 1, 'id': 3461},
#   {'hashtag_name': '3D', 'CNM_Label': 8, 'id': 18},
#   {'hashtag_name': 'Polygonal', 'CNM_Label': 8, 'id': 1258},
#   {'hashtag_name': 'hospital', 'CNM_Label': 6, 'id': 2522},
#   {'hashtag_name': 'icon', 'CNM_Label': 8, 'id': 2546},
#   {'hashtag_name': 'pandemic', 'CNM_Label': 8, 'id': 2898},
#   {'hashtag_name': 'tech', 'CNM_Label': 14, 'id': 3274},
#   {'hashtag_name': '3dprinting', 'CNM_Label': 2, 'id': 21},
#   {'hashtag_name': 'diy', 'CNM_Label': 2, 'id': 2265},
#   {'hashtag_name': 'italy', 'CNM_Label': 2, 'id': 2605},
#   {'hashtag_name': 'respirator', 'CNM_Label': 2, 'id': 3069},
#   {'hashtag_name': '3weeksprevents', 'CNM_Label': 12, 'id': 22},
#   {'hashtag_name': 'StayTheFHome', 'CNM_Label': 1, 'id': 1544},
#   {'hashtag_name': 'love', 'CNM_Label': 12, 'id': 2706},
#   {'hashtag_name': '4thturning', 'CNM_Label': 36, 'id': 26},
#   {'hashtag_name': 'toiletpaper', 'CNM_Label': 36, 'id': 3320},
#   {'hashtag_name': '51stState', 'CNM_Label': 31, 'id': 27},
#   {'hashtag_name': 'America', 'CNM_Label': 31, 'id': 87},
#   {'hashtag_name': 'PuertoRico', 'CNM_Label': 31, 'id': 1285},
#   {'hashtag_name': 'manufacturer', 'CNM_Label': 31, 'id': 2726},
#   {'hashtag_name': 'pharmaceutical', 'CNM_Label': 31, 'id': 2937},
#   {'hashtag_name': '5G', 'CNM_Label': 18, 'id': 28},
#   {'hashtag_name': 'Huawei', 'CNM_Label': 18, 'id': 737},
#   {'hashtag_name': 'Wuhan', 'CNM_Label': 18, 'id': 1855},
#   {'hashtag_name': 'eHealth', 'CNM_Label': 18, 'id': 2294},
#   {'hashtag_name': '603life', 'CNM_Label': 8, 'id': 29},
#   {'hashtag_name': 'safety', 'CNM_Label': 8, 'id': 3096},
#   {'hashtag_name': 'strength', 'CNM_Label': 8, 'id': 3233},
#   {'hashtag_name': 'AFG', 'CNM_Label': 12, 'id': 38},
#   {'hashtag_name': 'Breaking', 'CNM_Label': 26, 'id': 227},
#   {'hashtag_name': 'Herat', 'CNM_Label': 12, 'id': 713},
#   {'hashtag_name': 'AI', 'CNM_Label': 9, 'id': 42},
#   {'hashtag_name': 'DataScience', 'CNM_Label': 9, 'id': 417},
#   {'hashtag_name': 'Robots', 'CNM_Label': 9, 'id': 1356},
#   {'hashtag_name': 'bigdata', 'CNM_Label': 9, 'id': 1999},
#   {'hashtag_name': 'ARDS', 'CNM_Label': 7, 'id': 49},
#   {'hashtag_name': 'AcuteRespirtoryDisorder', 'CNM_Label': 7, 'id': 64},
#   {'hashtag_name': 'SocialDistancing', 'CNM_Label': 7, 'id': 1483},
#   {'hashtag_name': 'ATX', 'CNM_Label': 1, 'id': 56},
#   {'hashtag_name': 'Austin', 'CNM_Label': 1, 'id': 129},
#   {'hashtag_name': 'StayHomeSaveLives', 'CNM_Label': 1, 'id': 1534},
#   {'hashtag_name': 'AU', 'CNM_Label': 4, 'id': 57},
#   {'hashtag_name': 'Africa', 'CNM_Label': 4, 'id': 69},
#   {'hashtag_name': 'AcademicChatter', 'CNM_Label': 7, 'id': 60},
#   {'hashtag_name': 'AcademicTwitter', 'CNM_Label': 7, 'id': 62},
#   {'hashtag_name': 'PhDLife', 'CNM_Label': 7, 'id': 1236},
#   {'hashtag_name': 'ozchem', 'CNM_Label': 7, 'id': 2892},
#   {'hashtag_name': 'twitterchem', 'CNM_Label': 7, 'id': 3350},
#   {'hashtag_name': 'AcademicDog', 'CNM_Label': 7, 'id': 61},
#   {'hashtag_name': 'FlattenTheCurve', 'CNM_Label': 7, 'id': 577},
#   {'hashtag_name': 'ActYourAge', 'CNM_Label': 26, 'id': 63},
#   {'hashtag_name': 'KAG', 'CNM_Label': 26, 'id': 845},
#   {'hashtag_name': 'KAG2020', 'CNM_Label': 38, 'id': 846},
#   {'hashtag_name': 'StopSpreadingPanic', 'CNM_Label': 26, 'id': 1557},
#   {'hashtag_name': 'Afg', 'CNM_Label': 2, 'id': 67},
#   {'hashtag_name': 'Iran', 'CNM_Label': 2, 'id': 802},
#   {'hashtag_name': 'Italy', 'CNM_Label': 2, 'id': 813},
#   {'hashtag_name': 'Spain', 'CNM_Label': 23, 'id': 1505},
#   {'hashtag_name': 'Afghanistan', 'CNM_Label': 12, 'id': 68},
#   {'hashtag_name': 'lockdown', 'CNM_Label': 12, 'id': 2695},
#   {'hashtag_name': 'Arusha', 'CNM_Label': 4, 'id': 117},
#   {'hashtag_name': 'Disease', 'CNM_Label': 4, 'id': 445},
#   {'hashtag_name': 'Health', 'CNM_Label': 4, 'id': 697},
#   {'hashtag_name': 'Liberia', 'CNM_Label': 4, 'id': 905},
#   {'hashtag_name': 'Somalia', 'CNM_Label': 4, 'id': 1494},
#   {'hashtag_name': 'Tanzania', 'CNM_Label': 4, 'id': 1607},
#   {'hashtag_name': 'YouChat7', 'CNM_Label': 4, 'id': 1875},
#   {'hashtag_name': 'Zimbabwe', 'CNM_Label': 4, 'id': 1885},
#   {'hashtag_name': 'African', 'CNM_Label': 4, 'id': 70},
#   {'hashtag_name': 'BritishAirways', 'CNM_Label': 9, 'id': 234},
#   {'hashtag_name': 'Ryanair', 'CNM_Label': 9, 'id': 1368},
#   {'hashtag_name': 'VirginAlantic', 'CNM_Label': 9, 'id': 1765},
#   {'hashtag_name': 'Alberta', 'CNM_Label': 6, 'id': 76},
#   {'hashtag_name': 'Calgary', 'CNM_Label': 6, 'id': 272},
#   {'hashtag_name': 'SpeakUp', 'CNM_Label': 6, 'id': 1508},
#   {'hashtag_name': 'healthcare', 'CNM_Label': 6, 'id': 2495},
#   {'hashtag_name': 'Ali', 'CNM_Label': 9, 'id': 80},
#   {'hashtag_name': 'healthCare', 'CNM_Label': 9, 'id': 2492},
#   {'hashtag_name': 'Alphabet', 'CNM_Label': 5, 'id': 85},
#   {'hashtag_name': 'California', 'CNM_Label': 5, 'id': 273},
#   {'hashtag_name': 'Verily', 'CNM_Label': 5, 'id': 1760},
#   {'hashtag_name': 'Amazon', 'CNM_Label': 19, 'id': 86},
#   {'hashtag_name': 'BadTech', 'CNM_Label': 19, 'id': 155},
#   {'hashtag_name': 'BigTech', 'CNM_Label': 19, 'id': 191},
#   {'hashtag_name': 'Corporatism', 'CNM_Label': 19, 'id': 372},
#   {'hashtag_name': 'Economics101', 'CNM_Label': 19, 'id': 500},
#   {'hashtag_name': 'Quarantine', 'CNM_Label': 19, 'id': 1296},
#   {'hashtag_name': 'WholeFoods', 'CNM_Label': 19, 'id': 1832},
#   {'hashtag_name': 'bigBoxStores', 'CNM_Label': 19, 'id': 1998},
#   {'hashtag_name': 'smallBizowner', 'CNM_Label': 19, 'id': 3166},
#   {'hashtag_name': 'Cornoavirus', 'CNM_Label': 31, 'id': 368},
#   {'hashtag_name': 'Democrats', 'CNM_Label': 16, 'id': 434},
#   {'hashtag_name': 'Donors', 'CNM_Label': 31, 'id': 460},
#   {'hashtag_name': 'FlawedcastCLE', 'CNM_Label': 31, 'id': 579},
#   {'hashtag_name': 'PSA', 'CNM_Label': 31, 'id': 1199},
#   {'hashtag_name': 'Pandemic', 'CNM_Label': 22, 'id': 1208},
#   {'hashtag_name': 'Republicans', 'CNM_Label': 5, 'id': 1336},
#   {'hashtag_name': 'SelfIsolation', 'CNM_Label': 19, 'id': 1431},
#   {'hashtag_name': 'UBIStimulus', 'CNM_Label': 31, 'id': 1717},
#   {'hashtag_name': 'calm', 'CNM_Label': 31, 'id': 2061},
#   {'hashtag_name': 'frontpage', 'CNM_Label': 9, 'id': 2410},
#   {'hashtag_name': 'generous', 'CNM_Label': 31, 'id': 2426},
#   {'hashtag_name': 'kind', 'CNM_Label': 31, 'id': 2636},
#   {'hashtag_name': '新冠肺炎', 'CNM_Label': 9, 'id': 3481},
#   {'hashtag_name': '新型コロナウイルス', 'CNM_Label': 9, 'id': 3482},
#   {'hashtag_name': 'Americans', 'CNM_Label': 19, 'id': 90},
#   {'hashtag_name': 'StayHome', 'CNM_Label': 3, 'id': 1532},
#   {'hashtag_name': 'Trump', 'CNM_Label': 5, 'id': 1682},
#   {'hashtag_name': 'Trumptheprofiteer', 'CNM_Label': 19, 'id': 1699},
#   {'hashtag_name': 'Americas', 'CNM_Label': 5, 'id': 91},
#   {'hashtag_name': 'ShelterInPlace', 'CNM_Label': 5, 'id': 1445},
#   {'hashtag_name': 'TPHoarders', 'CNM_Label': 5, 'id': 1592},
#   {'hashtag_name': 'Anxiety', 'CNM_Label': 3, 'id': 102},
#   {'hashtag_name': 'Fear', 'CNM_Label': 3, 'id': 561},
#   {'hashtag_name': 'Panic', 'CNM_Label': 3, 'id': 1212},
#   {'hashtag_name': 'Apple', 'CNM_Label': 12, 'id': 104},
#   {'hashtag_name': 'AppleStore', 'CNM_Label': 12, 'id': 105},
#   {'hashtag_name': 'Arcturus', 'CNM_Label': 9, 'id': 107},
#   {'hashtag_name': 'CUREVAC', 'CNM_Label': 9, 'id': 268},
#   {'hashtag_name': 'MODERNA', 'CNM_Label': 9, 'id': 952},
#   {'hashtag_name': 'vaccine', 'CNM_Label': 9, 'id': 3375},
#   {'hashtag_name': 'Argentina', 'CNM_Label': 30, 'id': 108},
#   {'hashtag_name': 'Economy', 'CNM_Label': 30, 'id': 501},
#   {'hashtag_name': 'Impact', 'CNM_Label': 30, 'id': 778},
#   {'hashtag_name': 'LatinAmerica', 'CNM_Label': 30, 'id': 895},
#   {'hashtag_name': 'Venezuela', 'CNM_Label': 30, 'id': 1759},
#   {'hashtag_name': 'Arnie', 'CNM_Label': 1, 'id': 112},
#   {'hashtag_name': 'Artwork', 'CNM_Label': 6, 'id': 115},
#   {'hashtag_name': 'MyCharacter', 'CNM_Label': 6, 'id': 1073},
#   {'hashtag_name': 'covıd19', 'CNM_Label': 6, 'id': 2193},
#   {'hashtag_name': 'โควิด_19', 'CNM_Label': 6, 'id': 3503},
#   {'hashtag_name': 'โควิท_19', 'CNM_Label': 6, 'id': 3504},
#   {'hashtag_name': 'Asia', 'CNM_Label': 13, 'id': 119},
#   {'hashtag_name': 'HongKong', 'CNM_Label': 13, 'id': 730},
#   {'hashtag_name': 'Taiwan', 'CNM_Label': 13, 'id': 1603},
#   {'hashtag_name': 'US', 'CNM_Label': 18, 'id': 1726},
#   {'hashtag_name': 'ofc', 'CNM_Label': 13, 'id': 2858},
#   {'hashtag_name': 'AsktheQ', 'CNM_Label': 1, 'id': 121},
#   {'hashtag_name': 'QAnon', 'CNM_Label': 1, 'id': 1290},
#   {'hashtag_name': 'ThesePeopleAreSick', 'CNM_Label': 1, 'id': 1645},
#   {'hashtag_name': 'panicshopping', 'CNM_Label': 1, 'id': 2907},
#   {'hashtag_name': 'sheeple', 'CNM_Label': 1, 'id': 3144},
#   {'hashtag_name': 'Atlanta', 'CNM_Label': 34, 'id': 126},
#   {'hashtag_name': 'Georgia', 'CNM_Label': 19, 'id': 638},
#   {'hashtag_name': 'Houston', 'CNM_Label': 34, 'id': 733},
#   {'hashtag_name': 'LA', 'CNM_Label': 34, 'id': 876},
#   {'hashtag_name': 'NYC', 'CNM_Label': 34, 'id': 1099},
#   {'hashtag_name': 'SanAntonio', 'CNM_Label': 34, 'id': 1408},
#   {'hashtag_name': 'SanFransisco', 'CNM_Label': 34, 'id': 1409},
#   {'hashtag_name': 'AustralianID', 'CNM_Label': 8, 'id': 131},
#   {'hashtag_name': 'CoVid19', 'CNM_Label': 8, 'id': 341},
#   {'hashtag_name': 'ID', 'CNM_Label': 8, 'id': 747},
#   {'hashtag_name': 'IDMedicalCommunity', 'CNM_Label': 8, 'id': 750},
#   {'hashtag_name': 'IDPhysician', 'CNM_Label': 8, 'id': 751},
#   {'hashtag_name': 'InfectiousDisease', 'CNM_Label': 8, 'id': 791},
#   {'hashtag_name': 'AvoidCrowds', 'CNM_Label': 3, 'id': 133},
#   {'hashtag_name': 'StayAtHome', 'CNM_Label': 3, 'id': 1529},
#   {'hashtag_name': 'WashYourHands', 'CNM_Label': 3, 'id': 1804},
#   {'hashtag_name': 'AzureMaps', 'CNM_Label': 6, 'id': 134},
#   {'hashtag_name': 'opensource', 'CNM_Label': 6, 'id': 2873},
#   {'hashtag_name': 'BANG', 'CNM_Label': 27, 'id': 135},
#   {'hashtag_name': 'music', 'CNM_Label': 27, 'id': 2793},
#   {'hashtag_name': 'musicvideo', 'CNM_Label': 27, 'id': 2794},
#   {'hashtag_name': 'newmusic', 'CNM_Label': 27, 'id': 2819},
#   {'hashtag_name': 'radio', 'CNM_Label': 27, 'id': 3031},
#   {'hashtag_name': 'videoshoot', 'CNM_Label': 27, 'id': 3383},
#   {'hashtag_name': 'visuals', 'CNM_Label': 27, 'id': 3391},
#   {'hashtag_name': 'BBC', 'CNM_Label': 9, 'id': 136},
#   {'hashtag_name': 'TV', 'CNM_Label': 9, 'id': 1599},
#   {'hashtag_name': 'free', 'CNM_Label': 9, 'id': 2406},
#   {'hashtag_name': 'BBCan8', 'CNM_Label': 1, 'id': 137},
#   {'hashtag_name': 'BCHealth', 'CNM_Label': 18, 'id': 139},
#   {'hashtag_name': 'bcpoli', 'CNM_Label': 18, 'id': 1970},
#   {'hashtag_name': 'cdnpoli', 'CNM_Label': 18, 'id': 2088},
#   {'hashtag_name': 'BCM', 'CNM_Label': 12, 'id': 140},
#   {'hashtag_name': 'remotework', 'CNM_Label': 12, 'id': 3058},
#   {'hashtag_name': 'BILLIONAIRE', 'CNM_Label': 5, 'id': 142},
#   {'hashtag_name': 'BernieSanders', 'CNM_Label': 5, 'id': 181},
#   {'hashtag_name': 'Congress', 'CNM_Label': 5, 'id': 355},
#   {'hashtag_name': 'Conservative', 'CNM_Label': 5, 'id': 356},
#   {'hashtag_name': 'DonaldTrump', 'CNM_Label': 5, 'id': 458},
#   {'hashtag_name': 'Industry', 'CNM_Label': 5, 'id': 785},
#   {'hashtag_name': 'JoeBiden', 'CNM_Label': 5, 'id': 837},
#   {'hashtag_name': 'MarketCrash', 'CNM_Label': 5, 'id': 983},
#   {'hashtag_name': 'Moderate', 'CNM_Label': 5, 'id': 1035},
#   {'hashtag_name': 'StatusQuo', 'CNM_Label': 5, 'id': 1528},
#   {'hashtag_name': 'BLOG', 'CNM_Label': 30, 'id': 143},
#   {'hashtag_name': 'communications', 'CNM_Label': 30, 'id': 2147},
#   {'hashtag_name': 'virus', 'CNM_Label': 30, 'id': 3389},
#   {'hashtag_name': 'BREAKING', 'CNM_Label': 17, 'id': 149},
#   {'hashtag_name': 'BreakingNews', 'CNM_Label': 17, 'id': 228},
#   {'hashtag_name': 'Charlottesville', 'CNM_Label': 17, 'id': 311},
#   {'hashtag_name': 'DowJones', 'CNM_Label': 10, 'id': 466},
#   {'hashtag_name': 'ISRAEL', 'CNM_Label': 17, 'id': 765},
#   {'hashtag_name': 'Israel', 'CNM_Label': 17, 'id': 807},
#   {'hashtag_name': 'LiveOnK2', 'CNM_Label': 17, 'id': 917},
#   {'hashtag_name': 'Michigan', 'CNM_Label': 17, 'id': 1013},
#   {'hashtag_name': 'News1st', 'CNM_Label': 17, 'id': 1129},
#   {'hashtag_name': 'NewsGang', 'CNM_Label': 17, 'id': 1131},
#   {'hashtag_name': 'NewsPicks', 'CNM_Label': 17, 'id': 1132},
#   {'hashtag_name': 'Odisha', 'CNM_Label': 23, 'id': 1160},
#   {'hashtag_name': 'Wales', 'CNM_Label': 17, 'id': 1795},
#   {'hashtag_name': 'news', 'CNM_Label': 17, 'id': 2820},
#   {'hashtag_name': 'BREAKINGNEWS', 'CNM_Label': 1, 'id': 150},
#   {'hashtag_name': 'ShutItDown', 'CNM_Label': 1, 'id': 1452},
#   {'hashtag_name': 'BROOKLYN', 'CNM_Label': 1, 'id': 151},
#   {'hashtag_name': 'delivery', 'CNM_Label': 1, 'id': 2239},
#   {'hashtag_name': 'laundry', 'CNM_Label': 1, 'id': 2657},
#   {'hashtag_name': 'parkslope', 'CNM_Label': 1, 'id': 2913},
#   {'hashtag_name': 'BaaghiTV', 'CNM_Label': 9, 'id': 153},
#   {'hashtag_name': 'International', 'CNM_Label': 9, 'id': 797},
#   {'hashtag_name': 'BailOut', 'CNM_Label': 5, 'id': 156},
#   {'hashtag_name': 'RuleOfLaw', 'CNM_Label': 5, 'id': 1364},
#   {'hashtag_name': 'Testing', 'CNM_Label': 5, 'id': 1626},
#   {'hashtag_name': 'Treatment', 'CNM_Label': 5, 'id': 1677},
#   {'hashtag_name': 'WeThePeople', 'CNM_Label': 5, 'id': 1817},
#   {'hashtag_name': 'Ballina', 'CNM_Label': 15, 'id': 157},
#   {'hashtag_name': 'staff', 'CNM_Label': 15, 'id': 3200},
#   {'hashtag_name': 'BanegaSwasthIndia', 'CNM_Label': 3, 'id': 158},
#   {'hashtag_name': 'MiddayMeals', 'CNM_Label': 3, 'id': 1018},
#   {'hashtag_name': 'handwashing', 'CNM_Label': 3, 'id': 2480},
#   {'hashtag_name': 'Bangladesh', 'CNM_Label': 2, 'id': 159},
#   {'hashtag_name': 'SAARC', 'CNM_Label': 2, 'id': 1369},
#   {'hashtag_name': 'SheikhHasina', 'CNM_Label': 2, 'id': 1444},
#   {'hashtag_name': 'quarantine', 'CNM_Label': 11, 'id': 3024},
#   {'hashtag_name': 'Barclays', 'CNM_Label': 35, 'id': 162},
#   {'hashtag_name': 'Burberry', 'CNM_Label': 35, 'id': 242},
#   {'hashtag_name': 'Hitachi', 'CNM_Label': 35, 'id': 721},
#   {'hashtag_name': 'Honda', 'CNM_Label': 35, 'id': 729},
#   {'hashtag_name': 'USA', 'CNM_Label': 35, 'id': 1728},
#   {'hashtag_name': 'Bayern', 'CNM_Label': 7, 'id': 164},
#   {'hashtag_name': 'PhysicalDistancing', 'CNM_Label': 7, 'id': 1240},
#   {'hashtag_name': 'Soeder', 'CNM_Label': 7, 'id': 1491},
#   {'hashtag_name': 'BeSafe', 'CNM_Label': 32, 'id': 169},
#   {'hashtag_name': 'FitnessMotivation', 'CNM_Label': 32, 'id': 576},
#   {'hashtag_name': 'SpreadLove', 'CNM_Label': 32, 'id': 1510},
#   {'hashtag_name': 'StayHealthy', 'CNM_Label': 32, 'id': 1531},
#   {'hashtag_name': 'StaySafe', 'CNM_Label': 32, 'id': 1542},
#   {'hashtag_name': 'TheDoughMan', 'CNM_Label': 32, 'id': 1634},
#   {'hashtag_name': 'handsanitiser', 'CNM_Label': 32, 'id': 2477},
#   {'hashtag_name': 'BeSafeEveryone', 'CNM_Label': 3, 'id': 170},
#   {'hashtag_name': 'ChernobylHBO', 'CNM_Label': 3, 'id': 313},
#   {'hashtag_name': 'StayAtHomeChallenge', 'CNM_Label': 3, 'id': 1530},
#   {'hashtag_name': 'montaged', 'CNM_Label': 3, 'id': 2778},
#   {'hashtag_name': 'BeSmart', 'CNM_Label': 24, 'id': 172},
#   {'hashtag_name': 'HOPE', 'CNM_Label': 24, 'id': 677},
#   {'hashtag_name': 'HappyMonday', 'CNM_Label': 24, 'id': 694},
#   {'hashtag_name': 'TeachYourKids', 'CNM_Label': 24, 'id': 1610},
#   {'hashtag_name': 'BeTheChange', 'CNM_Label': 1, 'id': 173},
#   {'hashtag_name': 'WeCanDoThis', 'CNM_Label': 1, 'id': 1812},
#   {'hashtag_name': 'rapidimplementation', 'CNM_Label': 1, 'id': 3038},
#   {'hashtag_name': 'scifi', 'CNM_Label': 1, 'id': 3121},
#   {'hashtag_name': 'telehealth', 'CNM_Label': 1, 'id': 3279},
#   {'hashtag_name': 'Bear', 'CNM_Label': 10, 'id': 174},
#   {'hashtag_name': 'DJIA', 'CNM_Label': 10, 'id': 408},
#   {'hashtag_name': 'NASDAQ', 'CNM_Label': 10, 'id': 1076},
#   {'hashtag_name': 'NYSE', 'CNM_Label': 10, 'id': 1101},
#   {'hashtag_name': 'Stock', 'CNM_Label': 10, 'id': 1550},
#   {'hashtag_name': 'Trading', 'CNM_Label': 10, 'id': 1673},
#   {'hashtag_name': 'BehindTheScene', 'CNM_Label': 1, 'id': 176},
#   {'hashtag_name': 'politics', 'CNM_Label': 16, 'id': 2961},
#   {'hashtag_name': 'Belarus', 'CNM_Label': 2, 'id': 178},
#   {'hashtag_name': 'Russia', 'CNM_Label': 2, 'id': 1365},
#   {'hashtag_name': 'Bengaluru', 'CNM_Label': 23, 'id': 179},
#   {'hashtag_name': 'Karnataka', 'CNM_Label': 5, 'id': 858},
#   {'hashtag_name': 'positive', 'CNM_Label': 23, 'id': 2969},
#   {'hashtag_name': 'techie', 'CNM_Label': 23, 'id': 3275},
#   {'hashtag_name': 'Bitcoin', 'CNM_Label': 1, 'id': 198},
#   {'hashtag_name': 'Democrat', 'CNM_Label': 5, 'id': 432},
#   {'hashtag_name': 'Dems', 'CNM_Label': 5, 'id': 435},
#   {'hashtag_name': 'FDR', 'CNM_Label': 5, 'id': 536},
#   {'hashtag_name': 'GoingDown', 'CNM_Label': 5, 'id': 656},
#   {'hashtag_name': 'Leadership', 'CNM_Label': 5, 'id': 897},
#   {'hashtag_name': 'MarketCrashes', 'CNM_Label': 5, 'id': 984},
#   {'hashtag_name': 'MedicareForAll', 'CNM_Label': 5, 'id': 1003},
#   {'hashtag_name': 'NewDEAL', 'CNM_Label': 5, 'id': 1123},
#   {'hashtag_name': 'ShutDownAmerica', 'CNM_Label': 5, 'id': 1451},
#   {'hashtag_name': 'Bhubaneswar', 'CNM_Label': 9, 'id': 187},
#   {'hashtag_name': 'Delhi', 'CNM_Label': 9, 'id': 428},
#   {'hashtag_name': 'BigMatchJohn', 'CNM_Label': 22, 'id': 189},
#   {'hashtag_name': 'JC', 'CNM_Label': 22, 'id': 815},
#   {'hashtag_name': 'JohnCena', 'CNM_Label': 22, 'id': 839},
#   {'hashtag_name': 'Raw', 'CNM_Label': 22, 'id': 1320},
#   {'hashtag_name': 'WWE', 'CNM_Label': 22, 'id': 1791},
#   {'hashtag_name': 'Wrestling', 'CNM_Label': 22, 'id': 1853},
#   {'hashtag_name': 'BigPharma', 'CNM_Label': 9, 'id': 190},
#   {'hashtag_name': 'Billings', 'CNM_Label': 21, 'id': 194},
#   {'hashtag_name': 'Libraries', 'CNM_Label': 21, 'id': 907},
#   {'hashtag_name': 'Montana', 'CNM_Label': 21, 'id': 1049},
#   {'hashtag_name': 'library', 'CNM_Label': 21, 'id': 2679},
#   {'hashtag_name': 'BioWeapon', 'CNM_Label': 10, 'id': 195},
#   {'hashtag_name': 'IllegalAliens', 'CNM_Label': 10, 'id': 773},
#   {'hashtag_name': 'MondayMood', 'CNM_Label': 10, 'id': 1040},
#   {'hashtag_name': 'PANIC', 'CNM_Label': 10, 'id': 1186},
#   {'hashtag_name': 'SanctuaryCities', 'CNM_Label': 10, 'id': 1410},
#   {'hashtag_name': 'mondaythoughts', 'CNM_Label': 10, 'id': 2776},
#   {'hashtag_name': 'BlindSheep', 'CNM_Label': 1, 'id': 202},
#   {'hashtag_name': 'Blochchain', 'CNM_Label': 14, 'id': 203},
#   {'hashtag_name': 'Crypto', 'CNM_Label': 14, 'id': 395},
#   {'hashtag_name': 'Entrepreneurs', 'CNM_Label': 14, 'id': 516},
#   {'hashtag_name': 'Fintech', 'CNM_Label': 14, 'id': 570},
#   {'hashtag_name': 'Forex', 'CNM_Label': 14, 'id': 589},
#   {'hashtag_name': 'Investments', 'CNM_Label': 14, 'id': 800},
#   {'hashtag_name': 'Bollywood', 'CNM_Label': 23, 'id': 207},
#   {'hashtag_name': 'India', 'CNM_Label': 23, 'id': 782},
#   {'hashtag_name': 'Video', 'CNM_Label': 23, 'id': 1762},
#   {'hashtag_name': 'movie', 'CNM_Label': 23, 'id': 2786},
#   {'hashtag_name': 'BookWorm', 'CNM_Label': 21, 'id': 210},
#   {'hashtag_name': 'books', 'CNM_Label': 21, 'id': 2021},
#   {'hashtag_name': 'BorisJohnson', 'CNM_Label': 9, 'id': 211},
#   {'hashtag_name': 'Brexit', 'CNM_Label': 9, 'id': 231},
#   {'hashtag_name': 'boristhemurderer', 'CNM_Label': 9, 'id': 2027},
#   {'hashtag_name': 'Bosnia', 'CNM_Label': 2, 'id': 212},
#   {'hashtag_name': 'UnaSanaCanton', 'CNM_Label': 2, 'id': 1739},
#   {'hashtag_name': 'migrants', 'CNM_Label': 2, 'id': 2760},
#   {'hashtag_name': 'BossLadiesIndia', 'CNM_Label': 24, 'id': 213},
#   {'hashtag_name': 'WeCanDoIt', 'CNM_Label': 24, 'id': 1811},
#   {'hashtag_name': 'smallbusiness', 'CNM_Label': 24, 'id': 3168},
#   {'hashtag_name': 'Bradford', 'CNM_Label': 20, 'id': 223},
#   {'hashtag_name': 'Feet', 'CNM_Label': 20, 'id': 565},
#   {'hashtag_name': 'OpenPodiatry', 'CNM_Label': 20, 'id': 1173},
#   {'hashtag_name': 'Podiatrist', 'CNM_Label': 20, 'id': 1250},
#   {'hashtag_name': 'BreakTheChain', 'CNM_Label': 7, 'id': 225},
#   {'hashtag_name': 'SocialDistancingNow', 'CNM_Label': 1, 'id': 1485},
#   {'hashtag_name': 'respectyourimmunesystem', 'CNM_Label': 7, 'id': 3068},
#   {'hashtag_name': 'BreakTheLink', 'CNM_Label': 19, 'id': 226},
#   {'hashtag_name': 'MAGA', 'CNM_Label': 26, 'id': 944},
#   {'hashtag_name': 'News', 'CNM_Label': 4, 'id': 1128},
#   {'hashtag_name': 'OSINT', 'CNM_Label': 26, 'id': 1156},
#   {'hashtag_name': 'RUMINT', 'CNM_Label': 26, 'id': 1315},
#   {'hashtag_name': 'Rogers', 'CNM_Label': 26, 'id': 1358},
#   {'hashtag_name': 'Toronto', 'CNM_Label': 10, 'id': 1669},
#   {'hashtag_name': 'WallSt', 'CNM_Label': 26, 'id': 1796},
#   {'hashtag_name': 'WallStreet', 'CNM_Label': 26, 'id': 1797},
#   {'hashtag_name': 'CVNews', 'CNM_Label': 17, 'id': 271},
#   {'hashtag_name': 'Egypt', 'CNM_Label': 17, 'id': 504},
#   {'hashtag_name': 'MeHole', 'CNM_Label': 17, 'id': 995},
#   {'hashtag_name': 'Odidha', 'CNM_Label': 17, 'id': 1159},
#   {'hashtag_name': 'TheGreatAwakening', 'CNM_Label': 17, 'id': 1637},
#   {'hashtag_name': 'ThePerfectStorm', 'CNM_Label': 17, 'id': 1641},
#   {'hashtag_name': 'TracaRadio', 'CNM_Label': 17, 'id': 1672},
#   {'hashtag_name': 'TruthBeTold', 'CNM_Label': 17, 'id': 1700},
#   {'hashtag_name': 'WorldNews', 'CNM_Label': 17, 'id': 1849},
#   {'hashtag_name': 'coroniavirus', 'CNM_Label': 17, 'id': 2175},
#   {'hashtag_name': 'Breathe', 'CNM_Label': 10, 'id': 229},
#   {'hashtag_name': 'MondayMotivation', 'CNM_Label': 10, 'id': 1042},
#   {'hashtag_name': 'Relax', 'CNM_Label': 10, 'id': 1330},
#   {'hashtag_name': 'EU', 'CNM_Label': 9, 'id': 495},
#   {'hashtag_name': 'FX', 'CNM_Label': 9, 'id': 544},
#   {'hashtag_name': 'GBPUSD', 'CNM_Label': 9, 'id': 605},
#   {'hashtag_name': 'Market', 'CNM_Label': 9, 'id': 982},
#   {'hashtag_name': 'vote', 'CNM_Label': 9, 'id': 3395},
#   {'hashtag_name': 'British', 'CNM_Label': 6, 'id': 233},
#   {'hashtag_name': 'Medical', 'CNM_Label': 6, 'id': 1000},
#   {'hashtag_name': 'architecture', 'CNM_Label': 6, 'id': 1935},
#   {'hashtag_name': 'publichealthengland', 'CNM_Label': 6, 'id': 3015},
#   {'hashtag_name': 'Bronx', 'CNM_Label': 34, 'id': 235},
#   {'hashtag_name': 'FREE', 'CNM_Label': 34, 'id': 543},
#   {'hashtag_name': 'SchoolClosures', 'CNM_Label': 34, 'id': 1424},
#   {'hashtag_name': 'Brussels', 'CNM_Label': 9, 'id': 237},
#   {'hashtag_name': 'EuropeanUnion', 'CNM_Label': 9, 'id': 525},
#   {'hashtag_name': 'Buckam', 'CNM_Label': 15, 'id': 238},
#   {'hashtag_name': 'Caronavirus', 'CNM_Label': 15, 'id': 293},
#   {'hashtag_name': 'Florida', 'CNM_Label': 15, 'id': 580},
#   {'hashtag_name': 'BurkinaFaso', 'CNM_Label': 17, 'id': 244},
#   {'hashtag_name': 'Repost', 'CNM_Label': 15, 'id': 1334},
#   {'hashtag_name': 'Business', 'CNM_Label': 26, 'id': 245},
#   {'hashtag_name': 'Coroanvirus', 'CNM_Label': 26, 'id': 370},
#   {'hashtag_name': 'Markets', 'CNM_Label': 26, 'id': 986},
#   {'hashtag_name': 'Stocks', 'CNM_Label': 26, 'id': 1554},
#   {'hashtag_name': 'Tech', 'CNM_Label': 4, 'id': 1612},
#   {'hashtag_name': 'World', 'CNM_Label': 26, 'id': 1846},
#   {'hashtag_name': 'CC', 'CNM_Label': 17, 'id': 250},
#   {'hashtag_name': 'Poland', 'CNM_Label': 17, 'id': 1252},
#   {'hashtag_name': 'UAE', 'CNM_Label': 17, 'id': 1713},
#   {'hashtag_name': 'CCP', 'CNM_Label': 2, 'id': 251},
#   {'hashtag_name': 'MilesGuo', 'CNM_Label': 2, 'id': 1023},
#   {'hashtag_name': 'biowarfare', 'CNM_Label': 2, 'id': 2006},
#   {'hashtag_name': 'gerrymandering', 'CNM_Label': 2, 'id': 2429},
#   {'hashtag_name': 'CDC', 'CNM_Label': 5, 'id': 252},
#   {'hashtag_name': 'Cornavirus', 'CNM_Label': 5, 'id': 366},
#   {'hashtag_name': 'DevinNunes', 'CNM_Label': 5, 'id': 440},
#   {'hashtag_name': 'Dumkaupf', 'CNM_Label': 5, 'id': 477},
#   {'hashtag_name': 'FoxNews', 'CNM_Label': 5, 'id': 595},
#   {'hashtag_name': 'GOP', 'CNM_Label': 5, 'id': 612},
#   {'hashtag_name': 'CECC', 'CNM_Label': 13, 'id': 254},
#   {'hashtag_name': 'CEMA', 'CNM_Label': 25, 'id': 255},
#   {'hashtag_name': 'nenshi', 'CNM_Label': 25, 'id': 2812},
#   {'hashtag_name': 'stateofemergency', 'CNM_Label': 25, 'id': 3206},
#   {'hashtag_name': 'yyc', 'CNM_Label': 25, 'id': 3475},
#   {'hashtag_name': 'CHINA', 'CNM_Label': 18, 'id': 256},
#   {'hashtag_name': 'SARS', 'CNM_Label': 18, 'id': 1370},
#   {'hashtag_name': 'WuhanChina', 'CNM_Label': 18, 'id': 1856},
#   {'hashtag_name': 'WuhanChinaVirus', 'CNM_Label': 18, 'id': 1857},
#   {'hashtag_name': 'WuhanVirus', 'CNM_Label': 18, 'id': 1858},
#   {'hashtag_name': 'CNA', 'CNM_Label': 29, 'id': 262},
#   {'hashtag_name': 'EMT', 'CNM_Label': 29, 'id': 488},
#   {'hashtag_name': 'ER', 'CNM_Label': 29, 'id': 490},
#   {'hashtag_name': 'Ethics', 'CNM_Label': 29, 'id': 521},
#   {'hashtag_name': 'ICU', 'CNM_Label': 29, 'id': 746},
#   {'hashtag_name': 'COLON', 'CNM_Label': 1, 'id': 263},
#   {'hashtag_name': 'MaralagoVirus', 'CNM_Label': 1, 'id': 981},
#   {'hashtag_name': 'CV', 'CNM_Label': 6, 'id': 269},
#   {'hashtag_name': 'interview', 'CNM_Label': 6, 'id': 2583},
#   {'hashtag_name': 'video', 'CNM_Label': 6, 'id': 3381},
#   {'hashtag_name': 'CVID', 'CNM_Label': 10, 'id': 270},
#   {'hashtag_name': 'MondayMorning', 'CNM_Label': 10, 'id': 1041},
#   {'hashtag_name': 'RareDisease', 'CNM_Label': 10, 'id': 1319},
#   {'hashtag_name': 'NewYork', 'CNM_Label': 2, 'id': 1127},
#   {'hashtag_name': 'UnitedStates', 'CNM_Label': 2, 'id': 1742},
#   {'hashtag_name': 'CallOffShooting', 'CNM_Label': 30, 'id': 274},
#   {'hashtag_name': 'celebrities', 'CNM_Label': 30, 'id': 2091},
#   {'hashtag_name': 'selfy', 'CNM_Label': 30, 'id': 3138},
#   {'hashtag_name': 'Cambodia', 'CNM_Label': 2, 'id': 276},
#   {'hashtag_name': 'Canada', 'CNM_Label': 3, 'id': 278},
#   {'hashtag_name': 'MASKS', 'CNM_Label': 3, 'id': 945},
#   {'hashtag_name': 'SouthKorea', 'CNM_Label': 2, 'id': 1502},
#   {'hashtag_name': 'Winnipeg', 'CNM_Label': 3, 'id': 1835},
#   {'hashtag_name': 'Canadians', 'CNM_Label': 22, 'id': 281},
#   {'hashtag_name': 'FLU', 'CNM_Label': 22, 'id': 538},
#   {'hashtag_name': 'perspective', 'CNM_Label': 22, 'id': 2933},
#   {'hashtag_name': 'Canadianscientists', 'CNM_Label': 14, 'id': 282},
#   {'hashtag_name': 'Science', 'CNM_Label': 14, 'id': 1425},
#   {'hashtag_name': 'research', 'CNM_Label': 14, 'id': 3066},
#   {'hashtag_name': 'CancelTrump', 'CNM_Label': 10, 'id': 283},
#   {'hashtag_name': 'Cannabis', 'CNM_Label': 5, 'id': 284},
#   {'hashtag_name': 'ElPaso', 'CNM_Label': 5, 'id': 505},
#   {'hashtag_name': 'Food', 'CNM_Label': 5, 'id': 584},
#   {'hashtag_name': 'JimCrow', 'CNM_Label': 5, 'id': 833},
#   {'hashtag_name': 'President', 'CNM_Label': 5, 'id': 1271},
#   {'hashtag_name': 'Canton', 'CNM_Label': 19, 'id': 286},
#   {'hashtag_name': 'StatePark', 'CNM_Label': 19, 'id': 1525},
#   {'hashtag_name': 'Caracas', 'CNM_Label': 30, 'id': 287},
#   {'hashtag_name': 'CarbonTax', 'CNM_Label': 18, 'id': 288},
#   {'hashtag_name': 'Trudeau', 'CNM_Label': 18, 'id': 1681},
#   {'hashtag_name': 'CareForOthers', 'CNM_Label': 6, 'id': 289},
#   {'hashtag_name': 'HelpEachOther', 'CNM_Label': 7, 'id': 711},
#   {'hashtag_name': 'care', 'CNM_Label': 6, 'id': 2067},
#   {'hashtag_name': 'Casinos', 'CNM_Label': 4, 'id': 296},
#   {'hashtag_name': 'LasVegas', 'CNM_Label': 4, 'id': 892},
#   {'hashtag_name': 'Poker', 'CNM_Label': 4, 'id': 1251},
#   {'hashtag_name': 'CastillaYLeon', 'CNM_Label': 2, 'id': 297},
#   {'hashtag_name': 'donations', 'CNM_Label': 2, 'id': 2277},
#   {'hashtag_name': 'Catalonia', 'CNM_Label': 23, 'id': 298},
#   {'hashtag_name': 'Cats', 'CNM_Label': 7, 'id': 299},
#   {'hashtag_name': 'Catteningthecurve', 'CNM_Label': 7, 'id': 301},
#   {'hashtag_name': 'epitwitter', 'CNM_Label': 7, 'id': 2340},
#   {'hashtag_name': 'scicomm', 'CNM_Label': 7, 'id': 3119},
#   {'hashtag_name': 'Cattle', 'CNM_Label': 26, 'id': 302},
#   {'hashtag_name': 'beef', 'CNM_Label': 26, 'id': 1977},
#   {'hashtag_name': 'ranching', 'CNM_Label': 26, 'id': 3034},
#   {'hashtag_name': 'CherokeeCounty', 'CNM_Label': 19, 'id': 314},
#   {'hashtag_name': 'Chiba', 'CNM_Label': 2, 'id': 315},
#   {'hashtag_name': 'Japan', 'CNM_Label': 2, 'id': 827},
#   {'hashtag_name': 'japan', 'CNM_Label': 2, 'id': 2615},
#   {'hashtag_name': 'Chicken', 'CNM_Label': 23, 'id': 317},
#   {'hashtag_name': 'InsaneNews', 'CNM_Label': 23, 'id': 796},
#   {'hashtag_name': 'Jackfruit', 'CNM_Label': 23, 'id': 819},
#   {'hashtag_name': 'Children', 'CNM_Label': 18, 'id': 318},
#   {'hashtag_name': 'ChineseEnvoy', 'CNM_Label': 2, 'id': 324},
#   {'hashtag_name': 'DemDebate', 'CNM_Label': 10, 'id': 429},
#   {'hashtag_name': 'Europe', 'CNM_Label': 16, 'id': 523},
#   {'hashtag_name': 'ImranKhan', 'CNM_Label': 2, 'id': 779},
#   {'hashtag_name': 'Italia', 'CNM_Label': 2, 'id': 809},
#   {'hashtag_name': 'LNG', 'CNM_Label': 2, 'id': 883},
#   {'hashtag_name': 'NarendraModi', 'CNM_Label': 2, 'id': 1109},
#   {'hashtag_name': 'Pakistan', 'CNM_Label': 2, 'id': 1202},
#   {'hashtag_name': 'Singapore', 'CNM_Label': 2, 'id': 1460},
#   {'hashtag_name': 'Vietnam', 'CNM_Label': 2, 'id': 1764},
#   {'hashtag_name': 'WarandPeace', 'CNM_Label': 2, 'id': 1800},
#   {'hashtag_name': 'china', 'CNM_Label': 2, 'id': 2104},
#   {'hashtag_name': 'collapse', 'CNM_Label': 2, 'id': 2139},
#   {'hashtag_name': 'corronavirus', 'CNM_Label': 2, 'id': 2185},
#   {'hashtag_name': 'economics', 'CNM_Label': 2, 'id': 2304},
#   {'hashtag_name': 'emotions', 'CNM_Label': 2, 'id': 2322},
#   {'hashtag_name': 'global', 'CNM_Label': 11, 'id': 2437},
#   {'hashtag_name': 'impact', 'CNM_Label': 2, 'id': 2557},
#   {'hashtag_name': 'korea', 'CNM_Label': 2, 'id': 2647},
#   {'hashtag_name': 'natgas', 'CNM_Label': 2, 'id': 2803},
#   {'hashtag_name': 'slowdown', 'CNM_Label': 2, 'id': 3165},
#   {'hashtag_name': 'worldpowers', 'CNM_Label': 4, 'id': 3452},
#   {'hashtag_name': 'ChinaVirus', 'CNM_Label': 18, 'id': 321},
#   {'hashtag_name': 'FuckChina', 'CNM_Label': 18, 'id': 601},
#   {'hashtag_name': 'FuckXijinping', 'CNM_Label': 18, 'id': 603},
#   {'hashtag_name': 'Chinese', 'CNM_Label': 15, 'id': 323},
#   {'hashtag_name': 'kleptocracy', 'CNM_Label': 15, 'id': 2644},
#   {'hashtag_name': 'outbreak', 'CNM_Label': 15, 'id': 2887},
#   {'hashtag_name': 'ports', 'CNM_Label': 15, 'id': 2968},
#   {'hashtag_name': 'restaurants', 'CNM_Label': 15, 'id': 3073},
#   {'hashtag_name': 'takeaways', 'CNM_Label': 15, 'id': 3264},
#   {'hashtag_name': 'CitizenScience', 'CNM_Label': 18, 'id': 330},
#   {'hashtag_name': 'OpenData', 'CNM_Label': 18, 'id': 1172},
#   {'hashtag_name': 'ClassicalMusic', 'CNM_Label': 27, 'id': 332},
#   {'hashtag_name': 'Piano', 'CNM_Label': 27, 'id': 1242},
#   {'hashtag_name': 'ClickOnCare', 'CNM_Label': 40, 'id': 334},
#   {'hashtag_name': 'masks', 'CNM_Label': 40, 'id': 2737},
#   {'hashtag_name': 'namaste', 'CNM_Label': 40, 'id': 2802},
#   {'hashtag_name': 'netflix', 'CNM_Label': 40, 'id': 2814},
#   {'hashtag_name': 'netflixandchill', 'CNM_Label': 40, 'id': 2815},
#   {'hashtag_name': 'sanitizer', 'CNM_Label': 40, 'id': 3101},
#   {'hashtag_name': 'ClimateEmergency', 'CNM_Label': 13, 'id': 337},
#   {'hashtag_name': 'stocks', 'CNM_Label': 13, 'id': 3229},
#   {'hashtag_name': 'CoVID_19', 'CNM_Label': 22, 'id': 340},
#   {'hashtag_name': 'Day107', 'CNM_Label': 22, 'id': 420},
#   {'hashtag_name': 'SARS_CoV_2', 'CNM_Label': 22, 'id': 1374},
#   {'hashtag_name': 'TrumpVirus', 'CNM_Label': 22, 'id': 1694},
#   {'hashtag_name': 'Wuhan_2019_nCoV', 'CNM_Label': 22, 'id': 1859},
#   {'hashtag_name': 'nCoV', 'CNM_Label': 22, 'id': 2800},
#   {'hashtag_name': 'auspol', 'CNM_Label': 8, 'id': 1951},
#   {'hashtag_name': 'Cobra', 'CNM_Label': 30, 'id': 342},
#   {'hashtag_name': 'CobraMeeting', 'CNM_Label': 30, 'id': 343},
#   {'hashtag_name': 'beer', 'CNM_Label': 30, 'id': 1978},
#   {'hashtag_name': 'Coffee', 'CNM_Label': 10, 'id': 344},
#   {'hashtag_name': 'Commute', 'CNM_Label': 7, 'id': 352},
#   {'hashtag_name': 'Compassion', 'CNM_Label': 15, 'id': 353},
#   {'hashtag_name': 'FirstResponders', 'CNM_Label': 15, 'id': 575},
#   {'hashtag_name': 'caregivers', 'CNM_Label': 15, 'id': 2069},
#   {'hashtag_name': 'crisis', 'CNM_Label': 15, 'id': 2200},
#   {'hashtag_name': 'fatigue', 'CNM_Label': 15, 'id': 2365},
#   {'hashtag_name': 'DKShivakumar', 'CNM_Label': 5, 'id': 410},
#   {'hashtag_name': 'JaredKushner', 'CNM_Label': 5, 'id': 830},
#   {'hashtag_name': 'MikePence', 'CNM_Label': 5, 'id': 1021},
#   {'hashtag_name': 'WhiteHouse', 'CNM_Label': 5, 'id': 1830},
#   {'hashtag_name': 'Contagion', 'CNM_Label': 10, 'id': 358},
#   {'hashtag_name': 'StockMarket', 'CNM_Label': 10, 'id': 1551},
#   {'hashtag_name': 'StockMarketCrash', 'CNM_Label': 10, 'id': 1552},
#   {'hashtag_name': 'ControlThePandemic', 'CNM_Label': 35, 'id': 361},
#   {'hashtag_name': 'NoMoreDeaths', 'CNM_Label': 35, 'id': 1140},
#   {'hashtag_name': 'ShutDown14', 'CNM_Label': 35, 'id': 1450},
#   {'hashtag_name': 'ControlledByFear', 'CNM_Label': 3, 'id': 362},
#   {'hashtag_name': 'disease', 'CNM_Label': 3, 'id': 2258},
#   {'hashtag_name': 'Cornovirus', 'CNM_Label': 30, 'id': 369},
#   {'hashtag_name': 'CountryOverParty', 'CNM_Label': 5, 'id': 378},
#   {'hashtag_name': 'Senate', 'CNM_Label': 5, 'id': 1435},
#   {'hashtag_name': 'Shameless', 'CNM_Label': 5, 'id': 1440},
#   {'hashtag_name': 'CrimeMinisterMorrison', 'CNM_Label': 8, 'id': 388},
#   {'hashtag_name': 'LNPCrimeFamily', 'CNM_Label': 8, 'id': 885},
#   {'hashtag_name': 'qanda', 'CNM_Label': 8, 'id': 3022},
#   {'hashtag_name': 'Crisis', 'CNM_Label': 10, 'id': 390},
#   {'hashtag_name': 'WhatsInYour401K', 'CNM_Label': 10, 'id': 1826},
#   {'hashtag_name': 'Drunk', 'CNM_Label': 14, 'id': 472},
#   {'hashtag_name': 'bitcoin', 'CNM_Label': 14, 'id': 2008},
#   {'hashtag_name': 'miner', 'CNM_Label': 14, 'id': 2764},
#   {'hashtag_name': 'Cuba', 'CNM_Label': 2, 'id': 397},
#   {'hashtag_name': 'DoctorsPerCapita', 'CNM_Label': 2, 'id': 455},
#   {'hashtag_name': 'Ireland', 'CNM_Label': 2, 'id': 804},
#   {'hashtag_name': 'MSBraemar', 'CNM_Label': 2, 'id': 954},
#   {'hashtag_name': 'CyberSecurity', 'CNM_Label': 4, 'id': 401},
#   {'hashtag_name': 'Hackers', 'CNM_Label': 4, 'id': 684},
#   {'hashtag_name': 'Malware', 'CNM_Label': 4, 'id': 977},
#   {'hashtag_name': 'Technology', 'CNM_Label': 4, 'id': 1614},
#   {'hashtag_name': 'Cybercriminals', 'CNM_Label': 13, 'id': 402},
#   {'hashtag_name': 'cyberattack', 'CNM_Label': 13, 'id': 2214},
#   {'hashtag_name': 'databreach', 'CNM_Label': 13, 'id': 2224},
#   {'hashtag_name': 'infosec', 'CNM_Label': 13, 'id': 2571},
#   {'hashtag_name': 'pci', 'CNM_Label': 13, 'id': 2921},
#   {'hashtag_name': 'CyprusAirways', 'CNM_Label': 21, 'id': 403},
#   {'hashtag_name': 'airtravel', 'CNM_Label': 21, 'id': 1906},
#   {'hashtag_name': 'travel', 'CNM_Label': 21, 'id': 3343},
#   {'hashtag_name': 'DHA', 'CNM_Label': 17, 'id': 406},
#   {'hashtag_name': 'DJI', 'CNM_Label': 18, 'id': 407},
#   {'hashtag_name': 'stockmarketcrash', 'CNM_Label': 13, 'id': 3228},
#   {'hashtag_name': 'DataPrivacy', 'CNM_Label': 13, 'id': 416},
#   {'hashtag_name': 'PersonalData', 'CNM_Label': 13, 'id': 1232},
#   {'hashtag_name': 'PrincessCruises', 'CNM_Label': 13, 'id': 1273},
#   {'hashtag_name': 'data', 'CNM_Label': 13, 'id': 2222},
#   {'hashtag_name': 'DayTrading', 'CNM_Label': 10, 'id': 421},
#   {'hashtag_name': 'MondayMotivaton', 'CNM_Label': 10, 'id': 1043},
#   {'hashtag_name': 'DaytonStrong', 'CNM_Label': 5, 'id': 422},
#   {'hashtag_name': 'Ohio', 'CNM_Label': 5, 'id': 1163},
#   {'hashtag_name': 'DaytonaBeach', 'CNM_Label': 15, 'id': 423},
#   {'hashtag_name': 'DeepState', 'CNM_Label': 10, 'id': 426},
#   {'hashtag_name': 'France', 'CNM_Label': 4, 'id': 596},
#   {'hashtag_name': 'Germany', 'CNM_Label': 9, 'id': 639},
#   {'hashtag_name': 'DemocraticDebate', 'CNM_Label': 10, 'id': 433},
#   {'hashtag_name': 'Democracy', 'CNM_Label': 5, 'id': 431},
#   {'hashtag_name': 'DrainTheDeepState', 'CNM_Label': 5, 'id': 470},
#   {'hashtag_name': 'Libertarians', 'CNM_Label': 5, 'id': 906},
#   {'hashtag_name': 'Media', 'CNM_Label': 5, 'id': 999},
#   {'hashtag_name': 'Urgent', 'CNM_Label': 5, 'id': 1750},
#   {'hashtag_name': 'breaking_news', 'CNM_Label': 5, 'id': 2039},
#   {'hashtag_name': 'government', 'CNM_Label': 5, 'id': 2452},
#   {'hashtag_name': 'FakeNews', 'CNM_Label': 16, 'id': 552},
#   {'hashtag_name': 'FakeNewsMedia', 'CNM_Label': 16, 'id': 553},
#   {'hashtag_name': 'Leaders', 'CNM_Label': 5, 'id': 896},
#   {'hashtag_name': 'canada', 'CNM_Label': 16, 'id': 2062},
#   {'hashtag_name': 'compassion', 'CNM_Label': 5, 'id': 2152},
#   {'hashtag_name': 'liberals', 'CNM_Label': 16, 'id': 2677},
#   {'hashtag_name': 'trump', 'CNM_Label': 16, 'id': 3346},
#   {'hashtag_name': 'Designers', 'CNM_Label': 15, 'id': 439},
#   {'hashtag_name': 'Doctors', 'CNM_Label': 15, 'id': 454},
#   {'hashtag_name': 'Engineers', 'CNM_Label': 15, 'id': 512},
#   {'hashtag_name': 'Nurses', 'CNM_Label': 15, 'id': 1153},
#   {'hashtag_name': 'DigitalLifeAsia', 'CNM_Label': 8, 'id': 443},
#   {'hashtag_name': 'Disinfection', 'CNM_Label': 3, 'id': 447},
#   {'hashtag_name': 'surfaces', 'CNM_Label': 3, 'id': 3252},
#   {'hashtag_name': 'DoNotTouchYourFace', 'CNM_Label': 3, 'id': 452},
#   {'hashtag_name': 'USPresident', 'CNM_Label': 16, 'id': 1734},
#   {'hashtag_name': 'tourism', 'CNM_Label': 21, 'id': 3329},
#   {'hashtag_name': 'Donnybrook', 'CNM_Label': 32, 'id': 459},
#   {'hashtag_name': 'kidshomefun', 'CNM_Label': 32, 'id': 2633},
#   {'hashtag_name': 'DontHoard', 'CNM_Label': 21, 'id': 461},
#   {'hashtag_name': 'DontPanic', 'CNM_Label': 21, 'id': 462},
#   {'hashtag_name': 'Target', 'CNM_Label': 21, 'id': 1608},
#   {'hashtag_name': 'GetUnderstanding', 'CNM_Label': 21, 'id': 640},
#   {'hashtag_name': 'GetWisdom', 'CNM_Label': 21, 'id': 641},
#   {'hashtag_name': 'cdc', 'CNM_Label': 21, 'id': 2086},
#   {'hashtag_name': 'DontThinkJustPanic', 'CNM_Label': 1, 'id': 463},
#   {'hashtag_name': 'DowFutures', 'CNM_Label': 10, 'id': 465},
#   {'hashtag_name': 'nycschools', 'CNM_Label': 10, 'id': 2852},
#   {'hashtag_name': 'nycshutdown', 'CNM_Label': 10, 'id': 2853},
#   {'hashtag_name': 'MorningJoe', 'CNM_Label': 10, 'id': 1053},
#   {'hashtag_name': 'TrumpSlump', 'CNM_Label': 16, 'id': 1692},
#   {'hashtag_name': 'hammering', 'CNM_Label': 10, 'id': 2473},
#   {'hashtag_name': 'morningthoughts', 'CNM_Label': 10, 'id': 2783},
#   {'hashtag_name': 'prepper', 'CNM_Label': 10, 'id': 2985},
#   {'hashtag_name': 'Drones', 'CNM_Label': 4, 'id': 471},
#   {'hashtag_name': 'Innovation', 'CNM_Label': 4, 'id': 795},
#   {'hashtag_name': 'Police', 'CNM_Label': 4, 'id': 1253},
#   {'hashtag_name': 'Spy', 'CNM_Label': 4, 'id': 1513},
#   {'hashtag_name': 'Surveillance', 'CNM_Label': 4, 'id': 1571},
#   {'hashtag_name': 'Dubai', 'CNM_Label': 4, 'id': 474},
#   {'hashtag_name': 'booze', 'CNM_Label': 4, 'id': 2024},
#   {'hashtag_name': 'panic', 'CNM_Label': 4, 'id': 2901},
#   {'hashtag_name': 'DullesAirport', 'CNM_Label': 8, 'id': 475},
#   {'hashtag_name': 'DumpGOP', 'CNM_Label': 22, 'id': 478},
#   {'hashtag_name': 'DumpTrump', 'CNM_Label': 22, 'id': 479},
#   {'hashtag_name': 'FireGOP', 'CNM_Label': 22, 'id': 572},
#   {'hashtag_name': 'FireTrump', 'CNM_Label': 22, 'id': 573},
#   {'hashtag_name': 'TheRight', 'CNM_Label': 22, 'id': 1642},
#   {'hashtag_name': 'ECU360', 'CNM_Label': 14, 'id': 484},
#   {'hashtag_name': 'ShipWithAClick', 'CNM_Label': 14, 'id': 1447},
#   {'hashtag_name': 'freightforwarders', 'CNM_Label': 14, 'id': 2409},
#   {'hashtag_name': 'logistics', 'CNM_Label': 14, 'id': 2701},
#   {'hashtag_name': 'supplychain', 'CNM_Label': 14, 'id': 3246},
#   {'hashtag_name': 'technology', 'CNM_Label': 14, 'id': 3276},
#   {'hashtag_name': 'ES', 'CNM_Label': 10, 'id': 492},
#   {'hashtag_name': 'ESG', 'CNM_Label': 31, 'id': 493},
#   {'hashtag_name': 'leadership', 'CNM_Label': 31, 'id': 2662},
#   {'hashtag_name': 'EUROPE', 'CNM_Label': 33, 'id': 496},
#   {'hashtag_name': 'Romania', 'CNM_Label': 33, 'id': 1360},
#   {'hashtag_name': 'SARSCoV2', 'CNM_Label': 33, 'id': 1372},
#   {'hashtag_name': 'SIRCSWORLDNEWS', 'CNM_Label': 33, 'id': 1385},
#   {'hashtag_name': 'IDD', 'CNM_Label': 30, 'id': 748},
#   {'hashtag_name': 'Libya', 'CNM_Label': 17, 'id': 909},
#   {'hashtag_name': 'Mauritania', 'CNM_Label': 17, 'id': 993},
#   {'hashtag_name': 'Morocco', 'CNM_Label': 17, 'id': 1054},
#   {'hashtag_name': 'SEENews', 'CNM_Label': 17, 'id': 1380},
#   {'hashtag_name': 'Sisi', 'CNM_Label': 17, 'id': 1462},
#   {'hashtag_name': 'Sudan', 'CNM_Label': 17, 'id': 1568},
#   {'hashtag_name': 'Tunisia', 'CNM_Label': 17, 'id': 1707},
#   {'hashtag_name': 'breaking', 'CNM_Label': 17, 'id': 2038},
#   {'hashtag_name': 'sweden', 'CNM_Label': 17, 'id': 3258},
#   {'hashtag_name': 'فيروس_كورونا_المستجدّ',
#    'CNM_Label': 17,
#    'id': 3491},
#   {'hashtag_name': 'كورونا_مصر', 'CNM_Label': 17, 'id': 3494},
#   {'hashtag_name': 'EmergencyUBI', 'CNM_Label': 31, 'id': 509},
#   {'hashtag_name': 'HRes897', 'CNM_Label': 31, 'id': 680},
#   {'hashtag_name': 'WeNeedUBI', 'CNM_Label': 31, 'id': 1815},
#   {'hashtag_name': 'Enjoy', 'CNM_Label': 10, 'id': 514},
#   {'hashtag_name': 'Monday', 'CNM_Label': 10, 'id': 1038},
#   {'hashtag_name': 'StateofMind', 'CNM_Label': 10, 'id': 1526},
#   {'hashtag_name': 'Wonderful', 'CNM_Label': 10, 'id': 1840},
#   {'hashtag_name': 'YouHaveThePower', 'CNM_Label': 10, 'id': 1876},
#   {'hashtag_name': 'Life', 'CNM_Label': 14, 'id': 910},
#   {'hashtag_name': 'Money', 'CNM_Label': 14, 'id': 1047},
#   {'hashtag_name': 'employer', 'CNM_Label': 14, 'id': 2324},
#   {'hashtag_name': 'Estonia', 'CNM_Label': 2, 'id': 520},
#   {'hashtag_name': 'K9', 'CNM_Label': 2, 'id': 843},
#   {'hashtag_name': 'howitzer', 'CNM_Label': 2, 'id': 2528},
#   {'hashtag_name': 'Ethiopia', 'CNM_Label': 3, 'id': 522},
#   {'hashtag_name': 'lockdowns', 'CNM_Label': 16, 'id': 2697},
#   {'hashtag_name': 'Eurozone', 'CNM_Label': 22, 'id': 526},
#   {'hashtag_name': 'EverythingProperty', 'CNM_Label': 3, 'id': 528},
#   {'hashtag_name': 'Flowers', 'CNM_Label': 3, 'id': 581},
#   {'hashtag_name': 'Spring', 'CNM_Label': 3, 'id': 1511},
#   {'hashtag_name': 'TunbridgeWells', 'CNM_Label': 3, 'id': 1704},
#   {'hashtag_name': 'Expectations', 'CNM_Label': 32, 'id': 532},
#   {'hashtag_name': 'NoNewtonJokes', 'CNM_Label': 32, 'id': 1142},
#   {'hashtag_name': 'FAKENEWS', 'CNM_Label': 16, 'id': 535},
#   {'hashtag_name': 'TrumpTrain', 'CNM_Label': 16, 'id': 1693},
#   {'hashtag_name': 'americafirst', 'CNM_Label': 16, 'id': 1916},
#   {'hashtag_name': 'kag2020', 'CNM_Label': 16, 'id': 2628},
#   {'hashtag_name': 'maga', 'CNM_Label': 16, 'id': 2719},
#   {'hashtag_name': 'qanon', 'CNM_Label': 16, 'id': 3023},
#   {'hashtag_name': 'resist', 'CNM_Label': 16, 'id': 3067},
#   {'hashtag_name': 'voteblue', 'CNM_Label': 16, 'id': 3396},
#   {'hashtag_name': 'wwg1wga', 'CNM_Label': 16, 'id': 3462},
#   {'hashtag_name': 'Facts', 'CNM_Label': 3, 'id': 548},
#   {'hashtag_name': 'FactsAreFacts', 'CNM_Label': 8, 'id': 549},
#   {'hashtag_name': 'disability', 'CNM_Label': 8, 'id': 2255},
#   {'hashtag_name': 'hands', 'CNM_Label': 8, 'id': 2476},
#   {'hashtag_name': 'FactsMatter', 'CNM_Label': 14, 'id': 550},
#   {'hashtag_name': 'NeverForget', 'CNM_Label': 16, 'id': 1119},
#   {'hashtag_name': 'VoteBlue', 'CNM_Label': 16, 'id': 1775},
#   {'hashtag_name': 'FalseFlag', 'CNM_Label': 8, 'id': 554},
#   {'hashtag_name': 'MondayThoughts', 'CNM_Label': 8, 'id': 1044},
#   {'hashtag_name': 'Quarentine', 'CNM_Label': 8, 'id': 1301},
#   {'hashtag_name': 'FamiliesFirst', 'CNM_Label': 32, 'id': 555},
#   {'hashtag_name': 'MitchDoYourJob', 'CNM_Label': 32, 'id': 1032},
#   {'hashtag_name': 'ThankYouSpeakerPelosi', 'CNM_Label': 32, 'id': 1628},
#   {'hashtag_name': 'Farms', 'CNM_Label': 5, 'id': 557},
#   {'hashtag_name': 'Future', 'CNM_Label': 5, 'id': 604},
#   {'hashtag_name': 'Fashionista', 'CNM_Label': 1, 'id': 559},
#   {'hashtag_name': 'GoodMorning', 'CNM_Label': 1, 'id': 658},
#   {'hashtag_name': 'yt', 'CNM_Label': 1, 'id': 3474},
#   {'hashtag_name': 'FeedingFirstResponders', 'CNM_Label': 15, 'id': 564},
#   {'hashtag_name': 'NoDeliveryFee', 'CNM_Label': 15, 'id': 1138},
#   {'hashtag_name': 'Fermat', 'CNM_Label': 9, 'id': 566},
#   {'hashtag_name': 'catbonds', 'CNM_Label': 9, 'id': 2081},
#   {'hashtag_name': 'FiquemEmCasa', 'CNM_Label': 3, 'id': 571},
#   {'hashtag_name': 'GoodLife', 'CNM_Label': 7, 'id': 657},
#   {'hashtag_name': 'HandWashing', 'CNM_Label': 7, 'id': 686},
#   {'hashtag_name': 'Homeoffice', 'CNM_Label': 3, 'id': 728},
#   {'hashtag_name': 'KAICIID', 'CNM_Label': 7, 'id': 847},
#   {'hashtag_name': 'Keepcalm', 'CNM_Label': 31, 'id': 863},
#   {'hashtag_name': 'LEAPactivators', 'CNM_Label': 7, 'id': 879},
#   {'hashtag_name': 'PBC', 'CNM_Label': 7, 'id': 1189},
#   {'hashtag_name': 'PBCStrong', 'CNM_Label': 7, 'id': 1190},
#   {'hashtag_name': 'PCCM', 'CNM_Label': 7, 'id': 1191},
#   {'hashtag_name': 'QuarantineAndChill', 'CNM_Label': 12, 'id': 1298},
#   {'hashtag_name': 'RespiratoryHygiene', 'CNM_Label': 7, 'id': 1346},
#   {'hashtag_name': 'Stayhome', 'CNM_Label': 31, 'id': 1546},
#   {'hashtag_name': 'Telemedicine', 'CNM_Label': 7, 'id': 1619},
#   {'hashtag_name': 'TipOfTheDay', 'CNM_Label': 7, 'id': 1653},
#   {'hashtag_name': 'UnitedWeStand', 'CNM_Label': 7, 'id': 1743},
#   {'hashtag_name': 'WearAFuckingMask', 'CNM_Label': 7, 'id': 1820},
#   {'hashtag_name': 'WorkFromHome', 'CNM_Label': 12, 'id': 1844},
#   {'hashtag_name': 'binit', 'CNM_Label': 7, 'id': 2003},
#   {'hashtag_name': 'catchit', 'CNM_Label': 7, 'id': 2082},
#   {'hashtag_name': 'iorestocasa', 'CNM_Label': 27, 'id': 2590},
#   {'hashtag_name': 'killit', 'CNM_Label': 7, 'id': 2635},
#   {'hashtag_name': 'quedateEnTuCasa', 'CNM_Label': 27, 'id': 3026},
#   {'hashtag_name': 'religious', 'CNM_Label': 7, 'id': 3056},
#   {'hashtag_name': 'washyourhands', 'CNM_Label': 7, 'id': 3410},
#   {'hashtag_name': 'retirement', 'CNM_Label': 15, 'id': 3077},
#   {'hashtag_name': 'Flu', 'CNM_Label': 22, 'id': 582},
#   {'hashtag_name': 'Pneumonia', 'CNM_Label': 22, 'id': 1248},
#   {'hashtag_name': 'Travel', 'CNM_Label': 5, 'id': 1674},
#   {'hashtag_name': 'WeekendCoffeeShare', 'CNM_Label': 22, 'id': 1821},
#   {'hashtag_name': 'Flynn', 'CNM_Label': 35, 'id': 583},
#   {'hashtag_name': 'FoodDelivery', 'CNM_Label': 5, 'id': 585},
#   {'hashtag_name': 'Plenty', 'CNM_Label': 4, 'id': 1247},
#   {'hashtag_name': 'Restaurant', 'CNM_Label': 5, 'id': 1347},
#   {'hashtag_name': 'FortDetrick', 'CNM_Label': 30, 'id': 591},
#   {'hashtag_name': 'bio_warfare', 'CNM_Label': 30, 'id': 2004},
#   {'hashtag_name': 'God', 'CNM_Label': 4, 'id': 653},
#   {'hashtag_name': 'Macron', 'CNM_Label': 4, 'id': 965},
# ...
#   {'Edge_Freq': 1, 'source': 1534, 'target': 2551, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1534, 'target': 2590, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1534, 'target': 2885, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1534, 'target': 3026, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1534, 'target': 3028, 'color': 1},
#   {'Edge_Freq': 2, 'source': 57, 'target': 69, 'color': 1},
#   {'Edge_Freq': 1, 'source': 69, 'target': 117, 'color': 1},
#   {'Edge_Freq': 1, 'source': 69, 'target': 445, 'color': 1},
#   {'Edge_Freq': 1, 'source': 69, 'target': 697, 'color': 1},
#   {'Edge_Freq': 4, 'source': 69, 'target': 905, 'color': 1},
#   {'Edge_Freq': 2, 'source': 69, 'target': 1494, 'color': 1},
#   {'Edge_Freq': 5, 'source': 69, 'target': 1607, 'color': 1},
#   {'Edge_Freq': 1, 'source': 69, 'target': 1875, 'color': 1},
#   {'Edge_Freq': 1, 'source': 69, 'target': 1885, 'color': 1},
#   {'Edge_Freq': 2, 'source': 60, 'target': 62, 'color': 1},
#   {'Edge_Freq': 1, 'source': 60, 'target': 1236, 'color': 1},
#   {'Edge_Freq': 1, 'source': 60, 'target': 2892, 'color': 1},
#   {'Edge_Freq': 1, 'source': 60, 'target': 3350, 'color': 1},
#   {'Edge_Freq': 1, 'source': 62, 'target': 61, 'color': 1},
#   {'Edge_Freq': 1, 'source': 62, 'target': 577, 'color': 1},
#   {'Edge_Freq': 1, 'source': 62, 'target': 1236, 'color': 1},
#   {'Edge_Freq': 1, 'source': 62, 'target': 2892, 'color': 1},
#   {'Edge_Freq': 1, 'source': 62, 'target': 3350, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2892, 'target': 3350, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 164, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 225, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 299, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 301, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 358, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 657, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 686, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 728, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 847, 'color': 1},
#   {'Edge_Freq': 12, 'source': 577, 'target': 863, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 879, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1038, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1041, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1189, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1190, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1191, 'color': 1},
#   {'Edge_Freq': 12, 'source': 577, 'target': 1199, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1208, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1240, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1298, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1346, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1372, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1452, 'color': 0},
#   {'Edge_Freq': 2, 'source': 577, 'target': 1485, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1491, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1502, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1529, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1532, 'color': 0},
#   {'Edge_Freq': 12, 'source': 577, 'target': 1546, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1619, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1653, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1743, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 1820, 'color': 1},
#   {'Edge_Freq': 3, 'source': 577, 'target': 1844, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 2003, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 2082, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 2340, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 2590, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 2635, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 3026, 'color': 0},
#   {'Edge_Freq': 1, 'source': 577, 'target': 3056, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 3119, 'color': 1},
#   {'Edge_Freq': 1, 'source': 577, 'target': 3410, 'color': 1},
#   {'Edge_Freq': 1, 'source': 63, 'target': 845, 'color': 1},
#   {'Edge_Freq': 1, 'source': 63, 'target': 846, 'color': 0},
#   {'Edge_Freq': 1, 'source': 63, 'target': 1557, 'color': 1},
#   {'Edge_Freq': 1, 'source': 845, 'target': 466, 'color': 0},
#   {'Edge_Freq': 1, 'source': 845, 'target': 846, 'color': 0},
#   {'Edge_Freq': 1, 'source': 845, 'target': 944, 'color': 1},
#   {'Edge_Freq': 1, 'source': 845, 'target': 1557, 'color': 1},
#   {'Edge_Freq': 1, 'source': 845, 'target': 1796, 'color': 1},
#   {'Edge_Freq': 1, 'source': 845, 'target': 1797, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 1187, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 1289, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 1557, 'color': 0},
#   {'Edge_Freq': 1, 'source': 846, 'target': 1588, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 1683, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 1793, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 2221, 'color': 1},
#   {'Edge_Freq': 1, 'source': 846, 'target': 3299, 'color': 1},
#   {'Edge_Freq': 1, 'source': 67, 'target': 802, 'color': 1},
#   {'Edge_Freq': 1, 'source': 67, 'target': 813, 'color': 1},
#   {'Edge_Freq': 1, 'source': 67, 'target': 1505, 'color': 0},
#   {'Edge_Freq': 1, 'source': 802, 'target': 119, 'color': 0},
#   {'Edge_Freq': 1, 'source': 802, 'target': 763, 'color': 1},
#   {'Edge_Freq': 3, 'source': 802, 'target': 813, 'color': 1},
#   {'Edge_Freq': 1, 'source': 802, 'target': 869, 'color': 1},
#   {'Edge_Freq': 1, 'source': 802, 'target': 1276, 'color': 1},
#   {'Edge_Freq': 1, 'source': 802, 'target': 1365, 'color': 1},
#   {'Edge_Freq': 2, 'source': 802, 'target': 1505, 'color': 0},
#   {'Edge_Freq': 1, 'source': 802, 'target': 1726, 'color': 0},
#   {'Edge_Freq': 1, 'source': 802, 'target': 1728, 'color': 0},
#   {'Edge_Freq': 1, 'source': 802, 'target': 2104, 'color': 1},
#   {'Edge_Freq': 1, 'source': 802, 'target': 3100, 'color': 0},
#   {'Edge_Freq': 2, 'source': 813, 'target': 187, 'color': 0},
#   {'Edge_Freq': 1, 'source': 813, 'target': 397, 'color': 1},
#   {'Edge_Freq': 2, 'source': 813, 'target': 428, 'color': 0},
#   {'Edge_Freq': 1, 'source': 813, 'target': 455, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 732, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 792, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 804, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 809, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 827, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 1009, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 1453, 'color': 1},
#   {'Edge_Freq': 3, 'source': 813, 'target': 1505, 'color': 0},
#   {'Edge_Freq': 1, 'source': 813, 'target': 1728, 'color': 0},
#   {'Edge_Freq': 1, 'source': 813, 'target': 2277, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 2575, 'color': 0},
#   {'Edge_Freq': 1, 'source': 813, 'target': 2606, 'color': 1},
#   {'Edge_Freq': 1, 'source': 813, 'target': 2647, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 298, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 523, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 782, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 867, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 894, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 1065, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 1431, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 1436, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 1506, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 2495, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 2697, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 2851, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 2856, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 2969, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1505, 'target': 3288, 'color': 1},
#   {'Edge_Freq': 1, 'source': 68, 'target': 2695, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 104, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 105, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 596, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 798, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 806, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 920, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1120, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1286, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1298, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1436, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1481, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1529, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1532, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1620, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1728, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1917, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1932, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 1968, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2012, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2026, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2042, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2156, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2193, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2582, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2600, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2678, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2752, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2843, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2851, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2922, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 2923, 'color': 1},
#   {'Edge_Freq': 3, 'source': 2695, 'target': 3024, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 3181, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 3189, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 3248, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2695, 'target': 3301, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 3444, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2695, 'target': 3449, 'color': 1},
#   {'Edge_Freq': 1, 'source': 117, 'target': 905, 'color': 1},
#   {'Edge_Freq': 1, 'source': 117, 'target': 1494, 'color': 1},
#   {'Edge_Freq': 1, 'source': 117, 'target': 1607, 'color': 1},
#   {'Edge_Freq': 1, 'source': 445, 'target': 697, 'color': 1},
#   {'Edge_Freq': 1, 'source': 445, 'target': 1607, 'color': 1},
#   {'Edge_Freq': 2, 'source': 697, 'target': 252, 'color': 0},
#   {'Edge_Freq': 1, 'source': 697, 'target': 296, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 582, 'color': 0},
#   {'Edge_Freq': 1, 'source': 697, 'target': 610, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 709, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 793, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 886, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 892, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 912, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 998, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1052, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1201, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1208, 'color': 0},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1248, 'color': 0},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1251, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1406, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1494, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1607, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1654, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1674, 'color': 0},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1821, 'color': 0},
#   {'Edge_Freq': 1, 'source': 697, 'target': 1831, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 2493, 'color': 1},
#   {'Edge_Freq': 1, 'source': 697, 'target': 2976, 'color': 1},
#   {'Edge_Freq': 1, 'source': 905, 'target': 70, 'color': 1},
#   {'Edge_Freq': 1, 'source': 905, 'target': 1493, 'color': 1},
#   {'Edge_Freq': 2, 'source': 905, 'target': 1494, 'color': 1},
#   {'Edge_Freq': 8, 'source': 905, 'target': 1607, 'color': 1},
#   {'Edge_Freq': 1, 'source': 905, 'target': 1736, 'color': 1},
#   {'Edge_Freq': 1, 'source': 905, 'target': 1819, 'color': 1},
#   {'Edge_Freq': 1, 'source': 905, 'target': 2262, 'color': 1},
#   {'Edge_Freq': 1, 'source': 905, 'target': 3452, 'color': 1},
#   {'Edge_Freq': 6, 'source': 1494, 'target': 149, 'color': 0},
#   {'Edge_Freq': 2, 'source': 1494, 'target': 228, 'color': 0},
#   {'Edge_Freq': 1, 'source': 1494, 'target': 1037, 'color': 1},
#   {'Edge_Freq': 3, 'source': 1494, 'target': 1607, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1494, 'target': 1736, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1494, 'target': 3493, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1494, 'target': 3495, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1607, 'target': 70, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1607, 'target': 1736, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1607, 'target': 2916, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1875, 'target': 1885, 'color': 1},
#   {'Edge_Freq': 1, 'source': 234, 'target': 1368, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1368, 'target': 2463, 'color': 1},
#   {'Edge_Freq': 1, 'source': 76, 'target': 272, 'color': 1},
#   {'Edge_Freq': 1, 'source': 76, 'target': 1508, 'color': 1},
#   {'Edge_Freq': 1, 'source': 76, 'target': 2495, 'color': 1},
#   {'Edge_Freq': 1, 'source': 272, 'target': 1508, 'color': 1},
#   {'Edge_Freq': 1, 'source': 272, 'target': 2495, 'color': 1},
#   {'Edge_Freq': 1, 'source': 1508, 'target': 2495, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2495, 'target': 134, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2495, 'target': 233, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 523, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 803, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 814, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2495, 'target': 1000, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 1345, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2495, 'target': 1935, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2067, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2284, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2353, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2382, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2401, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2496, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2697, 'color': 0},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2742, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2495, 'target': 2873, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 2996, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 3001, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 3004, 'color': 1},
#   {'Edge_Freq': 2, 'source': 2495, 'target': 3015, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 3238, 'color': 1},
#   {'Edge_Freq': 1, 'source': 2495, 'target': 3372, 'color': 1},
#   {'Edge_Freq': 1, 'source': 80, 'target': 2492, 'color': 1},
#   {'Edge_Freq': 1, 'source': 85, 'target': 273, 'color': 1},
#   {'Edge_Freq': 1, 'source': 85, 'target': 1760, 'color': 1},
#   {'Edge_Freq': 1, 'source': 273, 'target': 252, 'color': 1},
#   {'Edge_Freq': 1, 'source': 273, 'target': 440, 'color': 1},
#   {'Edge_Freq': 1, 'source': 273, 'target': 477, 'color': 1},
#   ...]}

# %%
with open('GirvanNewman.json', 'w') as json_file:
    json.dump(data, json_file)

# %%
from networkx.readwrite import json_graph

GN = json_graph.node_link_graph(data)

# %%
degs = {}
for i in GN.nodes:
    degs[i] = GN.degree[i]

# %%
import networkx as nx
nx.set_node_attributes(GN, degs, 'Degree')

# %%
# Out:
# {'hashtag_name': 'QuarantineLife', 'CNM_Label': 1, 'Degree': 153}

# %%
GN_data = json_graph.node_link_data(GN)

# %%
with open('GirvanNewman.json', 'w') as json_file:
    json.dump(GN_data, json_file)
